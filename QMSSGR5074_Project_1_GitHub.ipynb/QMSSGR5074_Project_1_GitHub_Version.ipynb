# %% [markdown]
# **Author:**  Rongshan Wei, Lin Gan
#
# **Public GitHub Repository URL (Final Project Report & Code):**
#
# https://github.com/WrsRosanne/Projects-in-Advanced-Machine-Learning

# %% [markdown]
# # World Happiness Classification Competition
#
# ## Project Objectives
#
# This competition is designed to help you:
#
# - Develop a deep understanding of how machine learning models function
# - Understand the role and impact of model hyperparameters
# - Learn from systematic experimentation and model iteration
# - Produce a professional, well-structured notebook report
# - Publish the final project as a portfolio-ready GitHub repository
#
# ---
#
# ## Project Workflow
#
# You will complete the project through the following stages:
#
# 1. **Load and Merge Datasets**
#    - Import all relevant datasets
#    - Perform necessary joins and validation
#
# 2. **Data Preprocessing**
#    - Build preprocessing pipelines using `sklearn`'s `ColumnTransformer`
#    - Handle missing values, encoding, scaling, and feature engineering
#
# 3. **Model Training**
#    - Fit the model using the processed data
#    - Save both the preprocessing pipeline and trained model
#
# 4. **Prediction and Evaluation**
#    - Generate predictions
#    - Evaluate performance using appropriate metrics
#
# 5. **Hyperparameter Tuning**
#    - Systematically tune model parameters
#    - Compare performance across configurations
#
# 6. **Deep Learning Experimentation**
#    - Implement and evaluate a neural network approach
#    - Compare results with classical ML models
#
# 7. **Model Explainability (SHAP)**
#    - Apply SHAP for feature importance analysis
#    - Interpret and explain model decisions
#
# 8. **Final Report Submission**
#    - Clean and organize the notebook
#    - Ensure full reproducibility
#    - Upload the final report and code to a public GitHub repository

# %% [markdown]
# ---
#
# ## 0. Loading Datasets
#
# In this section, we load the **World Happiness 2023** datasets that will be used throughout the project.
#
# **Objectives of this stage:**
#
# - Import the datasets into the notebook environment
# - Inspect their structure and contents
# - Verify column names and data types
# - Identify potential inconsistencies before merging
#
# > Careful dataset inspection at this stage prevents downstream errors and ensures a clean modeling pipeline.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load the dataset
# Using relative paths, make sure the data file and Notebook are in the same folder
whr_df = pd.read_csv('WHR_2023.csv')

# Inspect the first few rows to understand the structure
whr_df.head()
# Out:
#        country                        region  happiness_score  gdp_per_capita  \
# 0      Finland                Western Europe            7.804           1.888
# 1      Denmark                Western Europe            7.586           1.949
# 2      Iceland                Western Europe            7.530           1.926
# 3       Israel  Middle East and North Africa            7.473           1.833
# 4  Netherlands                Western Europe            7.403           1.942
#
#    social_support  healthy_life_expectancy  freedom_to_make_life_choices  \
# 0           1.585                    0.535                         0.772
# 1           1.548                    0.537                         0.734
# 2           1.620                    0.559                         0.738
# 3           1.521                    0.577                         0.569
# 4           1.488                    0.545                         0.672
#
#    generosity  perceptions_of_corruption
# 0       0.126                      0.535
# 1       0.208                      0.525
# 2       0.250                      0.187
# 3       0.124                      0.158
# 4       0.251                      0.394

# %%
# Convert the regression target ('happiness_score') into classification labels
# We'll use quartiles to create 4 happiness categories: Very Low, Low, High, Very High

# Define quartiles
whr_df['happiness_category'] = pd.qcut(whr_df['happiness_score'],
                                       q=5,
                                       labels=['Very Low', 'Low', 'Average', 'High', 'Very High'])

# Select features and target
X = whr_df.drop(columns=['happiness_score', 'happiness_category'])
y = whr_df['happiness_category']

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Convert y_train and y_test to numerical labels
y_train_labels = y_train.astype('category').cat.codes
y_test_labels = y_test.astype('category').cat.codes

# %% [markdown]
# ### Conceptual Question

# %% [markdown]
# 1. What does `y_train.astype('category').cat.codes` do?
#
# It converts the string-based labels into a pandas categorical data type and then extracts their underlying integer codes. This step transforms human-readable text into a numerical format (e.g., 0, 1, 2, 3, 4) that machine learning algorithms and neural networks require for computation.
#
# 2. What is the difference between `y_train_labels` and `y_train`?
#
# `y_train` is a pandas Series containing the original string labels representing the distinct happiness categories (e.g., 'Very Low', 'High'). In contrast, `y_train_labels` contains the numerically encoded versions of those exact categories (e.g., 0, 3), which are formatted specifically to be fed into the models.

# %% [markdown]
# ### Add New Data

# %%
# Truncated and cleaned up region data to merge
countrydata=pd.read_csv("newcountryvars.csv")

countrydata.head()
# Out:
#   country_name  population  population_below_poverty_line       hdi  \
# 0        India  1339180127                           21.9  0.623559
# 1      Nigeria   190886311                           70.0  0.527105
# 2       Mexico   129163276                           46.2  0.761683
# 3     Pakistan   197015955                           29.5  0.550354
# 4   Bangladesh   164669751                           31.5  0.578824
#
#    life_expectancy  expected_years_of_schooling  mean_years_of_schooling  \
# 0           68.322                    11.696590                 6.298834
# 1           53.057                     9.970482                 6.000000
# 2           76.972                    13.299090                 8.554985
# 3           66.365                     8.106910                 5.089460
# 4           71.985                    10.178706                 5.241577
#
#             gni
# 0   5663.474799
# 1   5442.901264
# 2  16383.106680
# 3   5031.173074
# 4   3341.490722

# %%
# Merge in new data to X_train and X_test by taking "country" from first table and "country_name" from 2nd table.
# Also check which countries are common in both the datasets, and which type of merge will you perform for the best results.
# Hint: Look on the 'how' parameter of megre function of pandas.

# Using a left merge ensures that the number of samples in X_train and X_test remains unchanged.
X_train = X_train.merge(countrydata, left_on='country', right_on='country_name', how='left')
X_test = X_test.merge(countrydata, left_on='country', right_on='country_name', how='left')

# After merging, an extra redundant ‘country_name’ column (with the same content as ‘country’) will appear, drop it.
X_train = X_train.drop(columns=['country_name'])
X_test = X_test.drop(columns=['country_name'])

# %%
X_train.head(1)
# Out:
#       country              region  gdp_per_capita  social_support  \
# 0  Madagascar  Sub-Saharan Africa           0.632           0.779
#
#    healthy_life_expectancy  freedom_to_make_life_choices  generosity  \
# 0                    0.178                         0.187       0.177
#
#    perceptions_of_corruption  population  population_below_poverty_line  \
# 0                      0.134  25570895.0                           70.7
#
#         hdi  life_expectancy  expected_years_of_schooling  \
# 0  0.512149           65.515                     10.34614
#
#    mean_years_of_schooling          gni
# 0                 6.145955  1319.699397

# %% [markdown]
# ---
#
# ## 1. Exploratory Data Analysis and Visualization (EDAV)

# %%
print(X_train.dtypes)
# Out:
# country                           object
# region                            object
# gdp_per_capita                   float64
# social_support                   float64
# healthy_life_expectancy          float64
# freedom_to_make_life_choices     float64
# generosity                       float64
# perceptions_of_corruption        float64
# population                       float64
# population_below_poverty_line    float64
# hdi                              float64
# life_expectancy                  float64
# expected_years_of_schooling      float64
# mean_years_of_schooling          float64
# gni                              float64
# dtype: object

# %% [markdown]
# The output of `X_train.dtypes` reveals the following key characteristics of our feature set:
#
# 1. Mix of Data Types: The dataset consists of both numerical (`float64`, `int64`) and categorical (`object`) variables.
# 2. Categorical Features: Variables such as `country` and `region` are stored as `object` (string) types. Since machine learning models require numerical inputs, these features will need categorical encoding (e.g., One-Hot Encoding). Notably, `country` acts as a unique identifier and will likely need to be dropped before model training to prevent extreme overfitting, whereas `region` is a valuable grouping feature.
# 3. Numerical Features: The majority of the predictors (e.g., `gdp_per_capita`, `population`, `hdi`, `social_support`) are numerical. Because these variables are measured on completely different scales (e.g., raw population in millions vs. index scores between 0 and 1), applying a scaling technique like `StandardScaler` will be crucial during the preprocessing stage.
# 4. Clean Feature Space: The target variable (`happiness_category`) and the original `happiness_score` are successfully excluded from `X_train`, confirming that our feature matrix is ready for independent analysis without data leakage.

# %% [markdown]
# ### Missing Values Analysis
#
# Compute the number and percentage of missing values for each column and present the results in a clear summary table.

# %%
# Calculate the total number of missing values for each column
missing_count = X_train.isnull().sum()

# Calculate the percentage of missing values for each column
missing_percentage = (X_train.isnull().sum() / len(X_train)) * 100

# Create a summary DataFrame to present the results clearly
missing_summary = pd.DataFrame({
    'Missing Values': missing_count,
    'Percentage (%)': missing_percentage
})

# Sort the table in descending order based on the percentage of missing values
# Keep only the columns that actually have missing values for a cleaner view
missing_summary = missing_summary[missing_summary['Missing Values'] > 0].sort_values(by='Percentage (%)', ascending=False)

# Display the summary table
missing_summary
# Out:
#                                Missing Values  Percentage (%)
# population_below_poverty_line              16       16.842105
# expected_years_of_schooling                 7        7.368421
# life_expectancy                             7        7.368421
# mean_years_of_schooling                     7        7.368421
# gni                                         7        7.368421
# hdi                                         6        6.315789
# population                                  6        6.315789

# %% [markdown]
# ### Distribution of Key Numerical Features
#
# Select relevant numerical features and plot their histograms.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select key numerical features
key_features = ['gdp_per_capita', 'social_support', 'healthy_life_expectancy',
                'freedom_to_make_life_choices', 'mean_years_of_schooling', 'hdi']

# Set up the matplotlib figure with subplots (2 rows, 3 columns)
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(16, 10))
axes = axes.flatten()

# Loop through the selected features and plot their histograms with a KDE line
for i, feature in enumerate(key_features):
    if feature in X_train.columns:
        # Drop NA values just for the plot to avoid matplotlib errors
        plot_data = X_train[feature].dropna()
        sns.histplot(plot_data, kde=True, ax=axes[i], bins=20, color='skyblue')
        axes[i].set_title(f'Distribution of {feature}', fontsize=12)
        axes[i].set_xlabel(feature, fontsize=10)
        axes[i].set_ylabel('Frequency', fontsize=10)

# Adjust layout to prevent overlapping labels
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# 1. GDP per capita
# The distribution is slightly left-skewed, with most countries clustered at relatively higher GDP levels. This suggests that while many countries in the sample have moderate to high income levels, a small number remain significantly poorer.
#
# 2. Social support
# Social support appears left-skewed, with most observations concentrated between 1.0 and 1.5.
#
# 3. Healthy life expectancy
# This variable shows a roughly normal distribution, centered around 0.4–0.5. The spread suggests moderate variation in health outcomes across countries but generally within a similar range.
#
# 4. Freedom to make life choices
# The distribution is slightly left-skewed, with most values clustered around 0.5–0.7.
#
# 5. Mean years of schooling
# Mean years of schooling displays a mild right-skew, with most countries between 6 and 12 years of education.
#
# 6. HDI
# HDI is left-skewed, with most countries concentrated at higher development levels (0.7–0.9). A small number of lower-value observations indicate countries with significantly lower human development.

# %% [markdown]
# ### Distribution of Categorical Variables
#
# Plot the distribution of relevant categorical variables using appropriate visualizations (e.g., count plots or bar charts).

# %%
# Set up the figure for a single plot
plt.figure(figsize=(10, 6))

# Plot: Distribution of the 'region' feature
# Kept horizontal because region names are long, sorted by frequency
order_region = X_train['region'].value_counts().index
sns.countplot(y=X_train['region'], hue=X_train['region'], palette='Set2', order=order_region, legend=False)

plt.title('Distribution of Regions in Training Data', fontsize=14)
plt.xlabel('Count', fontsize=12)
plt.ylabel('Region', fontsize=12)

# Adjust layout to prevent clipping of long labels
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# The `region` feature exhibits a significant natural imbalance. Regions like "Sub-Saharan Africa", "Central and Eastern Europe", and "Western Europe" dominate the dataset, representing a large portion of the sample size. In contrast, regions like "North America and ANZ" and "Commonwealth of Independent States" have very few countries represented.

# %% [markdown]
# ### Feature Correlation Analysis
#
# Analyze the relationships between numerical features using correlation coefficients. Compute and visualize:
#
# - **Pearson correlation** — linear relationships
# - **Spearman correlation** — monotonic relationships
# - **Kendall correlation** — rank-based relationships

# %%
import numpy as np

# Select numerical columns for correlation analysis
num_cols = ['gdp_per_capita', 'social_support', 'healthy_life_expectancy',
            'freedom_to_make_life_choices', 'mean_years_of_schooling', 'hdi']

# Filter existing columns to avoid errors
num_data = X_train[[col for col in num_cols if col in X_train.columns]]

# Compute the three types of correlation matrices
corr_pearson = num_data.corr(method='pearson')
corr_spearman = num_data.corr(method='spearman')
corr_kendall = num_data.corr(method='kendall')

# Set up the matplotlib figure (1 row, 3 columns)
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(24, 7))

# Heatmap 1: Pearson (Linear relationships)
sns.heatmap(corr_pearson, annot=True, fmt=".2f", cmap='coolwarm',
            vmin=-1, vmax=1, ax=axes[0], square=True, cbar_kws={"shrink": .8})
axes[0].set_title('Pearson Correlation (Linear)', fontsize=14)

# Heatmap 2: Spearman (Monotonic relationships)
sns.heatmap(corr_spearman, annot=True, fmt=".2f", cmap='coolwarm',
            vmin=-1, vmax=1, ax=axes[1], square=True, cbar_kws={"shrink": .8})
axes[1].set_title('Spearman Correlation (Monotonic)', fontsize=14)

# Heatmap 3: Kendall (Rank-based relationships)
sns.heatmap(corr_kendall, annot=True, fmt=".2f", cmap='coolwarm',
            vmin=-1, vmax=1, ax=axes[2], square=True, cbar_kws={"shrink": .8})
axes[2].set_title('Kendall Correlation (Rank-based)', fontsize=14)

# Adjust layout
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# ### Bivariate Analysis and Relationship Exploration

# %% [markdown]
# By computing Pearson, Spearman, and Kendall correlations, we gain a multi-dimensional view of how our features interact:
#
# **Pearson vs. Spearman vs. Kendall:** We observe that while Spearman shows strong linear ties, the Pearson and Kendall coefficients remain high for pairs like `gdp_per_capita` and `hdi`. This confirms that their relationship is not just linear but consistently monotonicas one increases, the other almost always follows in rank.
#
# **Strong Positive Correlations:** A very high correlation (exceeding 0.80) is observed between `gdp_per_capita`, `hdi`, and `life_expectancy`. This is expected in socio-economic data, as higher national income typically funds better healthcare and infrastructure.
#
# **Multicollinearity Concerns:** The extreme correlation between `gdp_per_capita` and `hdi` (often > 0.90) indicates significant multicollinearity. In linear models, this would be a major issue, but for our Random Forest (Model 2), the impact is mitigated as tree-based models are naturally more robust to collinear features.
#
# The presence of high multicollinearity among macroeconomic variables explains why adding more similar features failed to improve model accuracy, the information gain was redundant.

# %%
# First, ensure the categories have a strictly logical order, which prevents pandas from re-ordering them alphabetically in plots
target_order = ['Very Low', 'Low', 'Average', 'High', 'Very High']
y_train = pd.Categorical(y_train, categories=target_order, ordered=True)

# Stacked Bar Chart: Region vs Target
if 'region' in X_train.columns:
    # Create the crosstab and IMMEDIATELY reindex columns to our logical order
    # This is the "magic" step that ensures the colors match the categories correctly
    region_target_crosstab = pd.crosstab(X_train['region'], y_train)[target_order]

    # Plotting with a sequential colormap (e.g., 'RdYlGn' from Red to Green)
    # Red will be 'Very Low', Green will be 'Very High'
    region_target_crosstab.plot(kind='bar', stacked=True, figsize=(14, 7),
                                colormap='RdYlGn', edgecolor='black')

    plt.title('Distribution of Happiness Categories within each Region', fontsize=14)
    plt.xlabel('Region', fontsize=12)
    plt.ylabel('Number of Countries', fontsize=12)
    plt.legend(title='Happiness Category', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# Box Plots: Num Features vs Target
num_features = ['gdp_per_capita', 'social_support', 'healthy_life_expectancy',
            'freedom_to_make_life_choices', 'mean_years_of_schooling', 'hdi']
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(16, 18))
axes = axes.flatten()

for i, feature in enumerate(num_features):
    if feature in X_train.columns:
        sns.boxplot(x=y_train, y=X_train[feature], ax=axes[i],
                    order=target_order, hue=y_train, palette='RdYlGn', legend=False)
        axes[i].set_title(f'{feature} across Happiness Categories', fontsize=13)
        axes[i].set_xlabel('Happiness Category', fontsize=11)
        axes[i].set_ylabel(feature, fontsize=11)

plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Regional "Happiness Clusters"
#
# The Stacked Bar Chart reveals significant geographic determinism. Sub-Saharan Africa is almost exclusively represented in the 'Very Low' and 'Low' categories, while Western Europe and North America dominate the 'High' and 'Very High' spectrum. The region feature is a powerful predictor. However, since the class distribution within regions is highly imbalanced, the model might over-rely on regional identity, leading to potential bias.
#
# 2. Strong Feature-Target Monotony
#
# The Box Plots confirm a nearly perfect monotonic relationship between the numerical features and the happiness_category. As it moves from 'Very Low' to 'Very High', the mean values of 6 numerical features show a continuous upward staircase trend. This high degree of separability suggests that the model will likely achieve high accuracy. However, the overlap between adjacent categories indicates that a simple linear boundary may struggle, justifying the use of non-linear models.

# %% [markdown]
# ### Outlier Detection
#
# Identify potential outliers in the numerical features using appropriate methods such as:
#
# - Box plots
# - Z-score analysis
# - Interquartile Range (IQR) method
#
# Highlight any significant anomalies and briefly comment on whether they should be retained, transformed, or removed.

# %%
# Using IQR method to identify potential outliers in the numerical features and print then all
for col in num_cols:
    if col in X_train.columns:
        # Calculate the IQR boundaries
        Q1 = X_train[col].quantile(0.25)
        Q3 = X_train[col].quantile(0.75)
        IQR = Q3 - Q1
        low, high = Q1 - 1.5 * IQR, Q3 + 1.5 * IQR

        # Detect outliers
        outliers = X_train[(X_train[col] < low) | (X_train[col] > high)].copy()

        if not outliers.empty:
            print(f"Feature: {col.upper()}")
            print(f"Normal Range: [{low:.3f} to {high:.3f}]")
            print(f"Detected {len(outliers)} outliers:")
            # Print country, region, and outliers
            cols = [c for c in ['country', 'region', col] if c in X_train.columns]
            print(outliers[cols].sort_values(by=col).to_string(index=False))
            print("-" * 50)
        else:
            print(f"Feature: {col.upper()} - No outliers detected.\n")

print("----All outliers has been printed----")
# Out:
# Feature: GDP_PER_CAPITA
# Normal Range: [0.001 to 2.898]
# Detected 1 outliers:
#   country                      region  gdp_per_capita
# Venezuela Latin America and Caribbean             0.0
# --------------------------------------------------
# Feature: SOCIAL_SUPPORT
# Normal Range: [0.332 to 2.014]
# Detected 2 outliers:
#     country             region  social_support
# Afghanistan         South Asia           0.000
#     Comoros Sub-Saharan Africa           0.327
# --------------------------------------------------
# Feature: HEALTHY_LIFE_EXPECTANCY - No outliers detected.
#
# Feature: FREEDOM_TO_MAKE_LIFE_CHOICES
# Normal Range: [0.152 to 0.956]
# Detected 3 outliers:
#     country                       region  freedom_to_make_life_choices
# Afghanistan                   South Asia                         0.000
#     Comoros           Sub-Saharan Africa                         0.117
#     Turkiye Middle East and North Africa                         0.125
# --------------------------------------------------
# Feature: MEAN_YEARS_OF_SCHOOLING - No outliers detected.
#
# Feature: HDI - No outliers detected.
#
# ----All outliers has been printed----

# %% [markdown]
# **In the social sciences, 0 generally represents NaN, meaning no data exists rather than the value itself being zero. Therefore, these special cases require handling.**

# %%
# Define the feature columns requiring zero-value cleanup.
cols_to_fix = ['gdp_per_capita', 'social_support', 'freedom_to_make_life_choices']

# Replace all zeros in X_train and X_test with NaN
for col in cols_to_fix:
    if col in X_train.columns:
        X_train[col] = X_train[col].replace(0, np.nan)
    if col in X_test.columns:
        X_test[col] = X_test[col].replace(0, np.nan)

# Examination results
print("Check for remaining zeros in fixed columns:")
print(X_train[cols_to_fix].eq(0).sum())
print("\nCheck for new NaNs (ready for imputer):")
print(X_train[cols_to_fix].isnull().sum())
# Out:
# Check for remaining zeros in fixed columns:
# gdp_per_capita                  0
# social_support                  0
# freedom_to_make_life_choices    0
# dtype: int64
#
# Check for new NaNs (ready for imputer):
# gdp_per_capita                  1
# social_support                  1
# freedom_to_make_life_choices    1
# dtype: int64

# %% [markdown]
# ### Key Findings from EDA
#
#
# **Strong Predictor Linearity & Monotony:**
# All six numerical features (GDP, Social Support, Life Expectancy, Freedom, Education, and HDI) show a clear, positive monotonic relationship with the target happiness_category. The staircase pattern in the box plots indicates that as these socioeconomic indicators increase, the likelihood of a country falling into a higher happiness quantile increases significantly.
#
# **Regional Determinism:**
# Geographic location is a massive proxy for happiness. Regions like Western Europe and North America are almost exclusively "High/Very High," while Sub-Saharan Africa and South Asia are heavily skewed toward "Very Low/Low." This suggests that region will be a dominant categorical feature for our model.
#
# **Identification of Data Artifacts:**
# We identified several 0.000 values in features like gdp_per_capita (Venezuela) and social_support/freedom (Afghanistan). Given the World Happiness Report's methodology, these are statistically impossible and represent data gaps rather than actual zero-states.
#
# **Missing Values and Outliers**
#
#
# **Outlier Retention Strategy:**
# Statistical outliers (calculated via the IQR method) were identified primarily in the lower bounds of social_support and freedom. We have chosen to retain these values (e.g., Afghanistan's extreme lows) as they represent genuine, albeit extreme, human conditions that are critical for the model to distinguish 'Very Low' happiness classes.
#
# **Missing Data Handling:**
# The aforementioned 0.000 artifacts have been converted to NaN. This ensures they are handled appropriately by our imputation strategy rather than being treated as valid extreme data points which would skew the neural network's weights.
#
# **Preprocessing and Feature Engineering**
#
#
# **Imputation:**
# A Median Imputer will be used to fill NaN values, as the median is more robust to the remaining extreme outliers than the mean.
#
# **Standardization:**
# Since we are employing a Multi-Layer Perceptron (MLP), feature scaling is non-negotiable. We will apply StandardScaler to ensure all numerical features have a mean of 0 and a standard deviation of 1, preventing high-magnitude features like mean_years_of_schooling from overpowering others during gradient descent.
#
# **One-Hot Encoding:**
# The region variable will be encoded into binary sparse vectors to allow the neural network to process regional influences without implying an arbitrary numerical order between continents.
#
# **Multicollinearity Management:**
# High correlation (Pearson $> 0.85$) between HDI, GDP, and Education was noted. While MLPs are generally robust to multicollinearity, we will monitor feature importance to ensure redundant information isn't causing overfitting.

# %% [markdown]
# ---
#
# ## 2. Feature Engineering
#
# Apply log transformations to normalize skewed numerical features and improve model stability (if applicable).

# %%
# Identify the numerical features that require normalization
# Check the skewness of all numerical features
print("Skewness Scores (Rule of thumb: > 1 means highly right-skewed):")
for col in num_cols:
    if col in X_train.columns:
        skew_score = X_train[col].skew()
        print(f" - {col}: {skew_score:.3f}")
# Out:
# Skewness Scores (Rule of thumb: > 1 means highly right-skewed):
#  - gdp_per_capita: -0.352
#  - social_support: -0.726
#  - healthy_life_expectancy: -0.368
#  - freedom_to_make_life_choices: -0.718
#  - mean_years_of_schooling: -0.437
#  - hdi: -0.453

# %% [markdown]
# Before applying any transformations, we quantitatively evaluated the skewness of our numerical features.
#
# **Finding:** None of our numerical features exhibited a severe positive skew (skewness > 1). Notably, `gdp_per_capita` in the World Happiness Report is typically already log-transformed by the publishers to linearize its relationship with happiness.
#
# **Action:** Applying an additional log transformation to already-normalized or left-skewed data would artificially distort the distributions (over-transformation). Therefore, we will deliberately bypass log transformations and rely on `StandardScaler` (Z-score normalization) in our pipeline to handle feature scaling.

# %% [markdown]
# Create at least one interaction feature to capture relationships between existing variables and enhance predictive power.

# %%
# We create an interaction feature between 'gdp_per_capita' and 'social_support'
# This captures the non-linear synergy between material wealth and social safety nets.
def add_interaction_feature(df):
    df_new = df.copy()
    if 'gdp_per_capita' in df_new.columns and 'social_support' in df_new.columns:
        df_new['gdp_social_interaction'] = df_new['gdp_per_capita'] * df_new['social_support']
    return df_new

# Apply to both Train and Test sets
X_train = add_interaction_feature(X_train)
X_test = add_interaction_feature(X_test)

# Visualize the new feature's distribution
fig, ax = plt.subplots(figsize=(8, 4))
sns.histplot(X_train['gdp_social_interaction'], kde=True, color='royalblue', ax=ax)
ax.set_title("Distribution of GDP & Social Support Interaction", fontsize=14, fontweight='bold')
ax.set_xlabel("GDP × Social Support", fontsize=12)
ax.set_ylabel("Frequency", fontsize=12)

plt.tight_layout()
plt.show()

# Display the updated feature list
print(f"Current numerical features count: {len([c for c in X_train.columns if X_train[c].dtype != 'object'])}")
# Out:
# Current numerical features count: 14

# %% [markdown]
# To capture cross-domain synergies, we explicitly engineered an interaction term: `gdp_social_interaction`.
#
# **Rationale:** While Neural Networks can theoretically map non-linear relationships, explicitly providing the interaction between economic resources (GDP) and interpersonal safety nets (Social Support) gives the model a strong, direct signal. It tests the well-being hypothesis that material wealth yields the highest happiness probabilities when paired with a strong community.

# %% [markdown]
# ---
#
# ## 3. Data Preprocessing
#
# Use `sklearn`'s `ColumnTransformer` to preprocess the data. Write a preprocessing function and save the fitted preprocessor for later use.

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# Create the preprocessing pipelines for both numeric and categorical data

# Drop categorical columns (and any other object types) to isolate numerical features
numeric_features_df = X_train.select_dtypes(include=['int64', 'float64'])
numeric_features = numeric_features_df.columns.tolist()

numeric_transformer = Pipeline(steps=[
    # 'Constant' with 0 is dangerous here. We use 'median' because it is robust to the extreme outliers we identified in our EDA
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# TA starter code assumes 'sub-region' exists, but our dataset only has 'region'
# We use a list comprehension to only include columns that actually exist
categorical_features = ['region', 'sub-region']
categorical_features = [col for col in categorical_features if col in X_train.columns]

# Replacing missing values with Modal value and then one hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    # handle_unknown='ignore' ensures the model doesn't crash if the test set
    # contains a region not seen during training.
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

# final preprocessor object set up with ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# Fit your preprocessor object
preprocess=preprocessor.fit(X_train)

# %% [markdown]
# ### Preprocessing Explanation
#
# The preprocessing pipeline systematically prepares raw data for the Multi-Layer Perceptron (MLP) model through the following steps:
#
# 1. **Numeric Imputation (`SimpleImputer`):** Fills missing values (`NaN`) in numerical columns so the model doesn't drop valuable rows.
# 2. **Standardization (`StandardScaler`):** Centers numerical features to have a mean of 0 and a standard deviation of 1. This is strictly required for neural networks, as large unscaled values (like `gdp_per_capita`) can cause exploding gradients and prevent the model's weights from converging properly.
# 3. **Categorical Imputation & Encoding (`OneHotEncoder`):** Fills missing geographic labels with the most frequent category (the mode). Then, it converts text labels (`region`, `sub-region`) into sparse binary arrays (1s and 0s) because neural networks cannot perform mathematical operations on raw text strings.
#
# #### Changes Made to the Imputation Strategy
#
# **What we changed:** we modified the `numeric_transformer` imputer from `strategy='constant', fill_value=0` to `strategy='median'`.
# For the `categorical_transformer`, we used `strategy='most_frequent'` and set the OneHotEncoder to `handle_unknown='ignore'`.
#
# **Why we made that change:**
# During our Exploratory Data Analysis (EDA), we identified that absolute `0.000` values in features like `social_support` and `freedom_to_make_life_choices` were actually data artifacts representing missing survey data, not true zeros. We previously converted these false zeros to `NaN`. If we used `fill_value=0`, we would re-inject those exact data errors back into our dataset. We selected the **median** strategy because it correctly estimates the missing values while remaining highly robust to the extreme socio-economic outliers (e.g., Afghanistan) we retained in our dataset.
#
# Furthermore, setting `handle_unknown='ignore'` is a necessary safeguard. If our test set or real-world inference data contains a new micro-region not present in the `X_train` data, the pipeline will gracefully assign it an all-zero one-hot vector instead of throwing a fatal execution error.

# %%
# function to transform data with preprocessor

def apply_preprocessing(data):
    # 1. Drop only the unused identification columns (e.g., 'country')
    # Do NOT drop 'region' as the OneHotEncoder expects it
    # Using errors='ignore' ensures it won't crash if the column is already gone
    clean_data = data.drop(['country'], axis=1, errors='ignore')

    # 2. Transform the data using the explicitly FITTED 'preprocess' object
    preprocessed_data = preprocess.transform(clean_data)

    return preprocessed_data

# Apply the function to our datasets to get them ready for the Neural Network
X_train_final = apply_preprocessing(X_train)
X_test_final = apply_preprocessing(X_test)

# %% [markdown]
# ### Conceptual Question: Object, Function, and Data Differences
#
# **1. The `preprocessor` object (Preprocessing object / Blueprint)**
# * **Essence**: It is an unfitted `ColumnTransformer` instance.
# * **Role**: It functions like a construction blueprint. It solely defines the rules for data processing (e.g., median imputation and normalization for numerical columns, one-hot encoding for categorical columns). At this stage, it is empty and has not learned any specific statistical characteristics about the data.
#
# **2. The `preprocess` object (Fitted Object / Experienced Brain)**
# * **Essence**: It is the fitted object produced after calling `preprocessor.fit(X_train)`.
# * **Function**: It acts like a skilled worker. Not only does it remember the rules from the blueprint, but it has also learned and saved all the specific statistical parameters from the training set `X_train` (e.g., calculating that the mean of GDP is 1.2, the median is 0.8, and remembering that `region` has 10 distinct continents). When processing the test set later, it strictly applies these fixed parameters learned from the training set to prevent data leakage.
#
# **3. The `preprocessor` function (Custom Function / Pipeline)**
# * **Essence**: This is a user-defined Python logic function (Callable Function), such as the `apply_preprocessing(data)` we defined above.
# * **Function**: It serves as an operation pipeline. It bundles preliminary cleaning actions (like removing redundant `country` columns) with core transformation operations (calling `preprocess.transform()`), enabling one-click automated processing for any new data (e.g., `X_test` or future samples).
#
# **4. The final `preprocessed_data` returned (Final Data / End Product)**
# * **Essence**: It is the final result returned by the function, typically a two-dimensional NumPy array.
# * **Function**: It represents the final output processed by the pipeline. At this stage, all missing values in the data have been imputed, all text labels (e.g., regions) have been converted into sparse matrices of `0`s and `1`s, and all numerical values have been scaled to a mean of 0 and variance of 1. This purely numerical matrix represents the final form ready to be fed directly into a neural network (MLP) for forward and backward propagation.

# %%
# check shape of X data after preprocessing it using our new function
apply_preprocessing(X_train).shape
# Out:
# (95, 24)

# %% [markdown]
# ---
#
# ## 4. Model Training and Saving Artifacts
#
# Fit the model on the preprocessed training data. Save the fitted preprocessor and the trained model for reuse (e.g., inference and submission).

# %%
from sklearn.ensemble import RandomForestClassifier
import pickle

# Define the Random Forest Model
model = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)

# Fit the model on the PREPROCESSED training data
model.fit(X_train_final, y_train)

# Score the model on the PREPROCESSED test data
test_accuracy = model.score(X_test_final, y_test)

print(f"Random Forest Model Accuracy on Test Set: {test_accuracy:.4f}")

# Save the artifacts using pickle library
# Saving the preprocessor blueprint
with open('fitted_preprocessor.pkl', 'wb') as f:
    pickle.dump(preprocess, f)

# Saving the trained model
with open('trained_rf_model.pkl', 'wb') as f:
    pickle.dump(model, f)

print("Model and Preprocessor successfully saved as .pkl files!")
# Out:
# Random Forest Model Accuracy on Test Set: 0.4762
# Model and Preprocessor successfully saved as .pkl files!

# %% [markdown]
# ---
#
# ## 5. Model Evaluation
#
# Generate predictions using `X_test`. Compare the predictions with the true labels in `y_test` using appropriate evaluation metrics.

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# Generate predicted values (Model 1)
prediction_labels = model.predict(apply_preprocessing(X_test))

# Generate and print the classification report
# This shows Precision, Recall, and F1-score for each individual happiness tier.
print("Classification Report:")
print("-" * 50)
print(classification_report(y_test, prediction_labels))

# Visualize the Confusion Matrix
# A clear visual representation of where the model gets confused
fig, ax = plt.subplots(figsize=(8, 6))

# Create the confusion matrix using the true labels and our predictions
cm = confusion_matrix(y_test, prediction_labels, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)

# Plot with a professional blue color map and rotated labels for readability
disp.plot(cmap='Blues', ax=ax, xticks_rotation=45)
ax.set_title('Confusion Matrix: Random Forest Predictions', fontsize=14, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# Classification Report:
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#      Average       0.44      0.50      0.47         8
#         High       0.62      0.62      0.62         8
#          Low       0.20      0.25      0.22         8
#    Very High       0.86      0.67      0.75         9
#     Very Low       0.38      0.33      0.35         9
#
#     accuracy                           0.48        42
#    macro avg       0.50      0.47      0.48        42
# weighted avg       0.51      0.48      0.49        42

# %% [markdown]
# 1. **High Precision on the Extremes:** The model performs exceptionally well at identifying 'Very High' happiness countries, boasting a Precision of 0.86 and an F1-score of 0.75. This indicates that our engineered features (such as the `gdp_social_interaction` term) successfully isolated the distinct socio-economic signatures of top-tier nations.
# 2. **The 'Middle-Class' Ambiguity:** The model struggles primarily with the 'Low' and 'Average' tiers (F1-scores of 0.22 and 0.47, respectively). This is an expected artifact of ordinal classification; the boundaries between lower-middle and middle-tier well-being are inherently fuzzy in the underlying survey data. Most misclassifications here are likely off-by-one adjacent errors rather than severe predictive failures.
# 3. **Overall Validity:** Given the small, balanced test set (42 instances, ~8 per class), achieving nearly 50% strict accuracy—along with 62%+ precision on the upper echelons—demonstrates that the Random Forest has effectively learned the core socio-economic drivers of happiness, performing 2.5x better than a random baseline (20%).

# %% [markdown]
# ---
#
# ## 6. Hyperparameter Experimentation
#
# Repeat the training and evaluation process with different model parameters to improve performance. Track results across experiments and report the best-performing configuration.

# %%
# Train model 2 using same preprocessor
from sklearn.ensemble import RandomForestClassifier

model_2 = RandomForestClassifier(
    n_estimators=300,
    max_depth=8,
    min_samples_split=4,
    min_samples_leaf=2,
    random_state=42,
    n_jobs=-1
)

model_2.fit(X_train_final, y_train)## Make a new model with changed parameters to improve the score
# Out:
# RandomForestClassifier(max_depth=8, min_samples_leaf=2, min_samples_split=4,
#                        n_estimators=300, n_jobs=-1, random_state=42)

# %% [markdown]
# ### Reflection on Hyperparameter Changes

# %% [markdown]
# In Model 2, we adjusted several Random Forest hyperparameters to try to improve model performance.
# Specifically, we changed `n_estimators`, `max_depth`, `min_samples_split`, and `min_samples_leaf`.
#
# The `n_estimators` parameter controls how many trees are built in the forest. Increasing the number of trees can make the model more stable and reduce variance. The `max_depth` parameter limits how deep each tree can grow, which helps prevent overfitting. The `min_samples_split` parameter controls the minimum number of samples required to split a node, and `min_samples_leaf` controls the minimum number of samples in a leaf node. Both of these parameters help make the model less sensitive to noise.
#
# After adjusting these parameters, the model performance improved compared to the baseline model. The accuracy increased from 0.4762 in Model 1 to 0.5714 in Model 2. This suggests that the updated parameter settings helped the model generalize better to the test data.

# %%
# Evaluate Model 2

# Generate predicted y values (Model 2)
from sklearn.metrics import accuracy_score, classification_report

prediction_labels = model_2.predict(X_test_final)

print("Accuracy:", accuracy_score(y_test, prediction_labels))
print(classification_report(y_test, prediction_labels))
# Out:
# Accuracy: 0.5714285714285714
#               precision    recall  f1-score   support
#
#      Average       0.62      0.62      0.62         8
#         High       0.67      0.75      0.71         8
#          Low       0.33      0.50      0.40         8
#    Very High       0.86      0.67      0.75         9
#     Very Low       0.50      0.33      0.40         9
#
#     accuracy                           0.57        42
#    macro avg       0.60      0.57      0.58        42
# weighted avg       0.60      0.57      0.58        42

# %% [markdown]
# ### Discussion

# %% [markdown]
# Trying random parameter values manually is not very efficient because it can take a lot of time and may miss good parameter combinations. Instead of guessing parameters repeatedly, a better approach is to use automated tuning methods such as GridSearchCV or RandomizedSearchCV. These methods systematically test different parameter combinations using cross-validation and help identify the best-performing configuration more reliably.

# %%
# Submit a third model using GridSearchCV

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

param_grid =param_grid = {
    'n_estimators': np.arange(100, 401, 100),
    'max_depth': [None, 5, 8, 10],
    'min_samples_split': [2, 4, 6],
    'min_samples_leaf': [1, 2, 3]}

# Create a RandomForestClassifier object
rf = RandomForestClassifier(random_state=42)

# GridSearchCV object
gridmodel =gridmodel = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

# Fit the GridSearchCV object to the preprocessed training data:
gridmodel.fit(X_train_final, y_train)

# Extract best score and parameter by calling objects "best_score_" and "best_params_"
print("best mean cross-validation score: {:.3f}".format(gridmodel.best_score_))
print("best parameters: {}".format(gridmodel.best_params_))

# Make predictions using the best model :
prediction_labels = gridmodel.predict(X_test_final)
# Out:
# best mean cross-validation score: 0.589
# best parameters: {'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': np.int64(200)}

# %%
#Submit Model 3

from sklearn.metrics import accuracy_score, classification_report

print("Accuracy:", accuracy_score(y_test, prediction_labels))
print(classification_report(y_test, prediction_labels))
# Out:
# Accuracy: 0.5
#               precision    recall  f1-score   support
#
#      Average       0.50      0.62      0.56         8
#         High       0.62      0.62      0.62         8
#          Low       0.27      0.38      0.32         8
#    Very High       0.86      0.67      0.75         9
#     Very Low       0.33      0.22      0.27         9
#
#     accuracy                           0.50        42
#    macro avg       0.52      0.50      0.50        42
# weighted avg       0.52      0.50      0.50        42

# %%
# Here are several classic ML architectures you can consider choosing from to experiment with next
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier


model = GradientBoostingClassifier(
    n_estimators=100,
    learning_rate=0.05,
    max_depth=3,
    random_state=42
)

model.fit(X_train_final, y_train)

# Generate predicted values
prediction_labels = model.predict(X_test_final)

## Show model performance by comparing prediction_labels with true labels
from sklearn.metrics import accuracy_score, classification_report

print("Accuracy:", accuracy_score(y_test, prediction_labels))
print(classification_report(y_test, prediction_labels))
# Out:
# Accuracy: 0.4523809523809524
#               precision    recall  f1-score   support
#
#      Average       0.42      0.62      0.50         8
#         High       0.57      0.50      0.53         8
#          Low       0.12      0.12      0.12         8
#    Very High       0.86      0.67      0.75         9
#     Very Low       0.38      0.33      0.35         9
#
#     accuracy                           0.45        42
#    macro avg       0.47      0.45      0.45        42
# weighted avg       0.48      0.45      0.46        42

# %% [markdown]
# ### Discussion

# %% [markdown]
# In this experiment, we tested several different models and tuning strategies to compare their performance. The baseline Random Forest model achieved an accuracy of 0.476. After manually adjusting the hyperparameters in Model 2, the accuracy improved to 0.571, which was the best result among the tested models.
#
# The GridSearchCV model achieved an accuracy of 0.50, which is slightly lower than the manually tuned model. This suggests that although automated tuning can be useful, it does not always guarantee better performance for every dataset.
#
# Finally, we tested a different algorithm, GradientBoostingClassifier, which achieved an accuracy of 0.452. This result is lower than the Random Forest models, suggesting that Random Forest may be better suited for this dataset.
#
# Overall, the experiments show that model performance can vary depending on both the algorithm and parameter choices, and comparing multiple approaches is an important step in machine learning workflows.

# %% [markdown]
# ---
#
# ## 7. Basic Deep Learning

# %%
# Now experiment with deep learning models
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation

# Preprocess input features

feature_count = X_train_final.shape[1]

keras_model = Sequential()

keras_model.add(Dense(128, activation='relu', input_shape=(feature_count,)))
keras_model.add(Dense(64, activation='relu'))
keras_model.add(Dense(64, activation='relu'))
keras_model.add(Dense(32, activation='relu'))

# Output layer (5 classes)
keras_model.add(Dense(5, activation='softmax'))

# Use Softmax activation in last layer. How many neurons should there be in the last layer? 5

# Encode categorical labels
from tensorflow.keras.utils import to_categorical
import numpy as np

y_train_encoded = to_categorical(pd.Categorical(y_train).codes)

# Compile model
keras_model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Fitting the NN to the Training set
history =keras_model.fit(
    X_train_final,
    y_train_encoded,
    batch_size=20,
    epochs=300,
    validation_split=0.25
)
# Out:
# Epoch 1/300
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.1955 - loss: 1.6492 - val_accuracy: 0.2500 - val_loss: 1.6256
# Epoch 2/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3356 - loss: 1.6069 - val_accuracy: 0.3333 - val_loss: 1.6171
# Epoch 3/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4038 - loss: 1.5775 - val_accuracy: 0.4167 - val_loss: 1.6088
# Epoch 4/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4257 - loss: 1.5586 - val_accuracy: 0.4167 - val_loss: 1.6006
# Epoch 5/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4765 - loss: 1.5307 - val_accuracy: 0.4167 - val_loss: 1.5954
# Epoch 6/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4855 - loss: 1.5014 - val_accuracy: 0.3750 - val_loss: 1.5899
# Epoch 7/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5322 - loss: 1.4799 - val_accuracy: 0.3750 - val_loss: 1.5850
# Epoch 8/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5038 - loss: 1.5023 - val_accuracy: 0.3750 - val_loss: 1.5798
# Epoch 9/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4868 - loss: 1.5041 - val_accuracy: 0.3750 - val_loss: 1.5748
# Epoch 10/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5188 - loss: 1.4416 - val_accuracy: 0.3750 - val_loss: 1.5696
# Epoch 11/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5262 - loss: 1.4424 - val_accuracy: 0.3750 - val_loss: 1.5647
# Epoch 12/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5005 - loss: 1.4283 - val_accuracy: 0.3333 - val_loss: 1.5597
# Epoch 13/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4849 - loss: 1.4043 - val_accuracy: 0.3333 - val_loss: 1.5540
# Epoch 14/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4515 - loss: 1.4171 - val_accuracy: 0.3333 - val_loss: 1.5482
# Epoch 15/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4488 - loss: 1.4177 - val_accuracy: 0.3333 - val_loss: 1.5434
# Epoch 16/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5215 - loss: 1.3396 - val_accuracy: 0.3333 - val_loss: 1.5366
# Epoch 17/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4655 - loss: 1.3516 - val_accuracy: 0.3333 - val_loss: 1.5312
# Epoch 18/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4915 - loss: 1.3236 - val_accuracy: 0.3333 - val_loss: 1.5255
# Epoch 19/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4892 - loss: 1.3059 - val_accuracy: 0.3333 - val_loss: 1.5180
# Epoch 20/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5092 - loss: 1.2741 - val_accuracy: 0.3333 - val_loss: 1.5116
# Epoch 21/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4892 - loss: 1.2964 - val_accuracy: 0.3333 - val_loss: 1.5062
# Epoch 22/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4492 - loss: 1.3045 - val_accuracy: 0.3333 - val_loss: 1.5003
# Epoch 23/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4815 - loss: 1.2714 - val_accuracy: 0.2917 - val_loss: 1.4940
# Epoch 24/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4776 - loss: 1.2305 - val_accuracy: 0.2917 - val_loss: 1.4892
# Epoch 25/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4442 - loss: 1.2657 - val_accuracy: 0.2917 - val_loss: 1.4846
# Epoch 26/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4626 - loss: 1.2388 - val_accuracy: 0.2500 - val_loss: 1.4788
# Epoch 27/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4959 - loss: 1.1951 - val_accuracy: 0.2500 - val_loss: 1.4740
# Epoch 28/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5015 - loss: 1.1705 - val_accuracy: 0.2500 - val_loss: 1.4677
# Epoch 29/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4599 - loss: 1.1836 - val_accuracy: 0.2500 - val_loss: 1.4639
# Epoch 30/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4749 - loss: 1.1941 - val_accuracy: 0.2500 - val_loss: 1.4587
# Epoch 31/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4382 - loss: 1.1919 - val_accuracy: 0.2500 - val_loss: 1.4544
# Epoch 32/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4982 - loss: 1.1750 - val_accuracy: 0.2500 - val_loss: 1.4500
# Epoch 33/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5182 - loss: 1.1219 - val_accuracy: 0.2500 - val_loss: 1.4447
# Epoch 34/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4832 - loss: 1.1519 - val_accuracy: 0.2500 - val_loss: 1.4430
# Epoch 35/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4449 - loss: 1.1242 - val_accuracy: 0.2500 - val_loss: 1.4343
# Epoch 36/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4682 - loss: 1.1567 - val_accuracy: 0.2500 - val_loss: 1.4295
# Epoch 37/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5072 - loss: 1.0948 - val_accuracy: 0.2500 - val_loss: 1.4242
# Epoch 38/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5055 - loss: 1.0806 - val_accuracy: 0.2500 - val_loss: 1.4195
# Epoch 39/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4922 - loss: 1.1071 - val_accuracy: 0.2500 - val_loss: 1.4154
# Epoch 40/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4738 - loss: 1.1024 - val_accuracy: 0.2500 - val_loss: 1.4105
# Epoch 41/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4882 - loss: 1.0636 - val_accuracy: 0.2500 - val_loss: 1.4054
# Epoch 42/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5272 - loss: 1.0235 - val_accuracy: 0.2500 - val_loss: 1.4020
# Epoch 43/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4978 - loss: 1.0851 - val_accuracy: 0.2500 - val_loss: 1.3979
# Epoch 44/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4491 - loss: 1.1147 - val_accuracy: 0.2500 - val_loss: 1.3951
# Epoch 45/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5095 - loss: 1.0528 - val_accuracy: 0.2917 - val_loss: 1.3894
# Epoch 46/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5101 - loss: 1.0219 - val_accuracy: 0.2917 - val_loss: 1.3868
# Epoch 47/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5691 - loss: 1.0071 - val_accuracy: 0.2917 - val_loss: 1.3840
# Epoch 48/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5058 - loss: 1.0288 - val_accuracy: 0.2917 - val_loss: 1.3790
# Epoch 49/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5631 - loss: 0.9693 - val_accuracy: 0.2917 - val_loss: 1.3774
# Epoch 50/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5470 - loss: 0.9917 - val_accuracy: 0.2917 - val_loss: 1.3720
# Epoch 51/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5820 - loss: 0.9468 - val_accuracy: 0.2917 - val_loss: 1.3645
# Epoch 52/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5627 - loss: 0.9909 - val_accuracy: 0.2917 - val_loss: 1.3585
# Epoch 53/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5231 - loss: 1.0052 - val_accuracy: 0.2917 - val_loss: 1.3580
# Epoch 54/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5497 - loss: 0.9928 - val_accuracy: 0.2917 - val_loss: 1.3562
# Epoch 55/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5114 - loss: 0.9918 - val_accuracy: 0.2917 - val_loss: 1.3491
# Epoch 56/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5804 - loss: 0.9351 - val_accuracy: 0.2917 - val_loss: 1.3458
# Epoch 57/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5420 - loss: 0.9794 - val_accuracy: 0.2917 - val_loss: 1.3452
# Epoch 58/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5943 - loss: 0.9442 - val_accuracy: 0.2917 - val_loss: 1.3378
# Epoch 59/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5870 - loss: 0.9362 - val_accuracy: 0.2500 - val_loss: 1.3365
# Epoch 60/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6020 - loss: 0.9010 - val_accuracy: 0.2917 - val_loss: 1.3308
# Epoch 61/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5843 - loss: 0.9078 - val_accuracy: 0.2500 - val_loss: 1.3242
# Epoch 62/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5710 - loss: 0.9157 - val_accuracy: 0.2500 - val_loss: 1.3252
# Epoch 63/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5883 - loss: 0.9437 - val_accuracy: 0.2917 - val_loss: 1.3239
# Epoch 64/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5666 - loss: 0.9150 - val_accuracy: 0.2917 - val_loss: 1.3263
# Epoch 65/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5873 - loss: 0.9379 - val_accuracy: 0.2917 - val_loss: 1.3258
# Epoch 66/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5983 - loss: 0.9052 - val_accuracy: 0.2500 - val_loss: 1.3207
# Epoch 67/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5535 - loss: 0.9249 - val_accuracy: 0.2500 - val_loss: 1.3196
# Epoch 68/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6285 - loss: 0.8777 - val_accuracy: 0.2500 - val_loss: 1.3188
# Epoch 69/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6196 - loss: 0.8581 - val_accuracy: 0.2500 - val_loss: 1.3206
# Epoch 70/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6165 - loss: 0.8613 - val_accuracy: 0.2500 - val_loss: 1.3184
# Epoch 71/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6129 - loss: 0.8997 - val_accuracy: 0.2083 - val_loss: 1.3187
# Epoch 72/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6815 - loss: 0.8744 - val_accuracy: 0.2083 - val_loss: 1.3183
# Epoch 73/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6688 - loss: 0.8516 - val_accuracy: 0.2083 - val_loss: 1.3205
# Epoch 74/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6854 - loss: 0.8540 - val_accuracy: 0.2500 - val_loss: 1.3141
# Epoch 75/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6994 - loss: 0.8256 - val_accuracy: 0.2500 - val_loss: 1.3114
# Epoch 76/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7144 - loss: 0.8385 - val_accuracy: 0.2083 - val_loss: 1.3142
# Epoch 77/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6494 - loss: 0.8531 - val_accuracy: 0.2083 - val_loss: 1.3139
# Epoch 78/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7190 - loss: 0.8138 - val_accuracy: 0.2500 - val_loss: 1.3099
# Epoch 79/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6388 - loss: 0.8254 - val_accuracy: 0.2500 - val_loss: 1.3048
# Epoch 80/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6598 - loss: 0.8302 - val_accuracy: 0.2500 - val_loss: 1.3022
# Epoch 81/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7167 - loss: 0.8316 - val_accuracy: 0.2500 - val_loss: 1.3005
# Epoch 82/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6967 - loss: 0.8310 - val_accuracy: 0.2500 - val_loss: 1.2984
# Epoch 83/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6265 - loss: 0.8429 - val_accuracy: 0.2500 - val_loss: 1.3010
# Epoch 84/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7263 - loss: 0.8437 - val_accuracy: 0.2500 - val_loss: 1.3055
# Epoch 85/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7330 - loss: 0.8093 - val_accuracy: 0.2500 - val_loss: 1.3089
# Epoch 86/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7263 - loss: 0.8212 - val_accuracy: 0.2500 - val_loss: 1.3095
# Epoch 87/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7094 - loss: 0.7757 - val_accuracy: 0.2500 - val_loss: 1.3024
# Epoch 88/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6967 - loss: 0.8009 - val_accuracy: 0.2500 - val_loss: 1.3016
# Epoch 89/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7400 - loss: 0.7927 - val_accuracy: 0.2500 - val_loss: 1.3066
# Epoch 90/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7036 - loss: 0.8278 - val_accuracy: 0.2500 - val_loss: 1.2989
# Epoch 91/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7586 - loss: 0.7551 - val_accuracy: 0.2500 - val_loss: 1.3004
# Epoch 92/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7286 - loss: 0.7715 - val_accuracy: 0.2500 - val_loss: 1.3042
# Epoch 93/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7219 - loss: 0.7845 - val_accuracy: 0.2500 - val_loss: 1.3069
# Epoch 94/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7709 - loss: 0.7512 - val_accuracy: 0.2500 - val_loss: 1.3053
# Epoch 95/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7715 - loss: 0.7641 - val_accuracy: 0.2500 - val_loss: 1.3095
# Epoch 96/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7686 - loss: 0.7854 - val_accuracy: 0.2500 - val_loss: 1.3099
# Epoch 97/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7792 - loss: 0.7687 - val_accuracy: 0.2500 - val_loss: 1.3040
# Epoch 98/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7526 - loss: 0.7613 - val_accuracy: 0.2500 - val_loss: 1.2957
# Epoch 99/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7053 - loss: 0.7787 - val_accuracy: 0.2500 - val_loss: 1.2985
# Epoch 100/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7023 - loss: 0.7726 - val_accuracy: 0.2500 - val_loss: 1.2982
# Epoch 101/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6790 - loss: 0.7753 - val_accuracy: 0.2500 - val_loss: 1.2994
# Epoch 102/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6880 - loss: 0.7443 - val_accuracy: 0.2500 - val_loss: 1.2946
# Epoch 103/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8032 - loss: 0.7251 - val_accuracy: 0.2500 - val_loss: 1.3053
# Epoch 104/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7682 - loss: 0.7508 - val_accuracy: 0.2500 - val_loss: 1.3039
# Epoch 105/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7613 - loss: 0.7233 - val_accuracy: 0.3333 - val_loss: 1.2998
# Epoch 106/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7765 - loss: 0.7517 - val_accuracy: 0.2917 - val_loss: 1.2984
# Epoch 107/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7565 - loss: 0.6989 - val_accuracy: 0.2917 - val_loss: 1.3018
# Epoch 108/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7992 - loss: 0.6942 - val_accuracy: 0.2917 - val_loss: 1.2917
# Epoch 109/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7738 - loss: 0.7118 - val_accuracy: 0.2917 - val_loss: 1.2987
# Epoch 110/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8105 - loss: 0.6986 - val_accuracy: 0.2917 - val_loss: 1.3006
# Epoch 111/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7786 - loss: 0.6739 - val_accuracy: 0.3333 - val_loss: 1.2981
# Epoch 112/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7636 - loss: 0.7157 - val_accuracy: 0.3333 - val_loss: 1.2908
# Epoch 113/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7665 - loss: 0.7090 - val_accuracy: 0.3333 - val_loss: 1.3000
# Epoch 114/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8438 - loss: 0.6669 - val_accuracy: 0.4167 - val_loss: 1.2835
# Epoch 115/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7542 - loss: 0.7542 - val_accuracy: 0.4583 - val_loss: 1.2869
# Epoch 116/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7688 - loss: 0.7135 - val_accuracy: 0.4583 - val_loss: 1.2968
# Epoch 117/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7965 - loss: 0.6866 - val_accuracy: 0.4583 - val_loss: 1.2970
# Epoch 118/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7982 - loss: 0.7229 - val_accuracy: 0.5000 - val_loss: 1.3008
# Epoch 119/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7838 - loss: 0.6555 - val_accuracy: 0.5000 - val_loss: 1.2918
# Epoch 120/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8011 - loss: 0.7188 - val_accuracy: 0.4167 - val_loss: 1.2970
# Epoch 121/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7722 - loss: 0.6875 - val_accuracy: 0.4167 - val_loss: 1.3004
# Epoch 122/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7988 - loss: 0.6989 - val_accuracy: 0.4167 - val_loss: 1.3034
# Epoch 123/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8065 - loss: 0.6241 - val_accuracy: 0.4167 - val_loss: 1.2954
# Epoch 124/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7765 - loss: 0.6490 - val_accuracy: 0.4167 - val_loss: 1.2977
# Epoch 125/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7259 - loss: 0.6788 - val_accuracy: 0.4583 - val_loss: 1.3012
# Epoch 126/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7778 - loss: 0.6689 - val_accuracy: 0.4583 - val_loss: 1.3073
# Epoch 127/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7359 - loss: 0.6496 - val_accuracy: 0.4583 - val_loss: 1.3168
# Epoch 128/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7469 - loss: 0.6319 - val_accuracy: 0.4583 - val_loss: 1.3040
# Epoch 129/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8134 - loss: 0.6721 - val_accuracy: 0.4583 - val_loss: 1.3105
# Epoch 130/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7726 - loss: 0.6560 - val_accuracy: 0.5000 - val_loss: 1.3089
# Epoch 131/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8222 - loss: 0.6189 - val_accuracy: 0.4583 - val_loss: 1.3165
# Epoch 132/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7403 - loss: 0.6739 - val_accuracy: 0.5000 - val_loss: 1.3181
# Epoch 133/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8107 - loss: 0.6343 - val_accuracy: 0.4583 - val_loss: 1.3165
# Epoch 134/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7995 - loss: 0.6391 - val_accuracy: 0.5000 - val_loss: 1.3211
# Epoch 135/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7918 - loss: 0.6789 - val_accuracy: 0.4583 - val_loss: 1.3187
# Epoch 136/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7955 - loss: 0.6496 - val_accuracy: 0.4583 - val_loss: 1.3204
# Epoch 137/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8218 - loss: 0.6305 - val_accuracy: 0.5000 - val_loss: 1.3268
# Epoch 138/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8045 - loss: 0.6220 - val_accuracy: 0.5000 - val_loss: 1.3146
# Epoch 139/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8437 - loss: 0.6424 - val_accuracy: 0.4583 - val_loss: 1.3288
# Epoch 140/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8247 - loss: 0.6531 - val_accuracy: 0.4583 - val_loss: 1.3340
# Epoch 141/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8664 - loss: 0.5854 - val_accuracy: 0.4583 - val_loss: 1.3270
# Epoch 142/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8730 - loss: 0.6080 - val_accuracy: 0.5000 - val_loss: 1.3316
# Epoch 143/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8420 - loss: 0.6496 - val_accuracy: 0.4583 - val_loss: 1.3368
# Epoch 144/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8230 - loss: 0.6227 - val_accuracy: 0.4583 - val_loss: 1.3310
# Epoch 145/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8570 - loss: 0.6215 - val_accuracy: 0.4583 - val_loss: 1.3342
# Epoch 146/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7801 - loss: 0.6042 - val_accuracy: 0.5000 - val_loss: 1.3237
# Epoch 147/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7803 - loss: 0.6564 - val_accuracy: 0.5417 - val_loss: 1.3305
# Epoch 148/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8870 - loss: 0.5558 - val_accuracy: 0.4583 - val_loss: 1.3324
# Epoch 149/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8341 - loss: 0.5865 - val_accuracy: 0.5417 - val_loss: 1.3356
# Epoch 150/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8787 - loss: 0.5774 - val_accuracy: 0.5000 - val_loss: 1.3463
# Epoch 151/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8670 - loss: 0.5748 - val_accuracy: 0.4583 - val_loss: 1.3461
# Epoch 152/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8297 - loss: 0.5894 - val_accuracy: 0.5000 - val_loss: 1.3356
# Epoch 153/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9053 - loss: 0.5707 - val_accuracy: 0.4583 - val_loss: 1.3418
# Epoch 154/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8447 - loss: 0.5783 - val_accuracy: 0.5000 - val_loss: 1.3413
# Epoch 155/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8191 - loss: 0.5879 - val_accuracy: 0.5417 - val_loss: 1.3443
# Epoch 156/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8803 - loss: 0.5599 - val_accuracy: 0.5000 - val_loss: 1.3371
# Epoch 157/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7807 - loss: 0.5660 - val_accuracy: 0.5000 - val_loss: 1.3352
# Epoch 158/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8351 - loss: 0.5455 - val_accuracy: 0.5417 - val_loss: 1.3423
# Epoch 159/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8264 - loss: 0.5730 - val_accuracy: 0.5000 - val_loss: 1.3535
# Epoch 160/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8257 - loss: 0.5439 - val_accuracy: 0.5417 - val_loss: 1.3520
# Epoch 161/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8830 - loss: 0.5031 - val_accuracy: 0.5000 - val_loss: 1.3561
# Epoch 162/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8380 - loss: 0.5441 - val_accuracy: 0.5000 - val_loss: 1.3571
# Epoch 163/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8487 - loss: 0.5438 - val_accuracy: 0.5000 - val_loss: 1.3555
# Epoch 164/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8397 - loss: 0.5607 - val_accuracy: 0.4583 - val_loss: 1.3702
# Epoch 165/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7991 - loss: 0.5694 - val_accuracy: 0.5000 - val_loss: 1.3738
# Epoch 166/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8068 - loss: 0.5273 - val_accuracy: 0.5417 - val_loss: 1.3573
# Epoch 167/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8370 - loss: 0.5643 - val_accuracy: 0.5000 - val_loss: 1.3753
# Epoch 168/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8670 - loss: 0.5289 - val_accuracy: 0.5000 - val_loss: 1.3620
# Epoch 169/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8624 - loss: 0.5243 - val_accuracy: 0.5417 - val_loss: 1.3822
# Epoch 170/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8391 - loss: 0.5338 - val_accuracy: 0.5417 - val_loss: 1.3679
# Epoch 171/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8130 - loss: 0.5324 - val_accuracy: 0.4583 - val_loss: 1.3907
# Epoch 172/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8453 - loss: 0.5172 - val_accuracy: 0.4583 - val_loss: 1.3911
# Epoch 173/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8630 - loss: 0.4758 - val_accuracy: 0.5000 - val_loss: 1.3985
# Epoch 174/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8387 - loss: 0.5490 - val_accuracy: 0.5000 - val_loss: 1.3884
# Epoch 175/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8770 - loss: 0.5335 - val_accuracy: 0.5000 - val_loss: 1.3856
# Epoch 176/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8470 - loss: 0.5038 - val_accuracy: 0.4583 - val_loss: 1.4003
# Epoch 177/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8257 - loss: 0.5313 - val_accuracy: 0.5417 - val_loss: 1.3978
# Epoch 178/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8287 - loss: 0.5365 - val_accuracy: 0.5000 - val_loss: 1.4271
# Epoch 179/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8670 - loss: 0.4652 - val_accuracy: 0.4583 - val_loss: 1.4155
# Epoch 180/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8570 - loss: 0.4924 - val_accuracy: 0.4583 - val_loss: 1.4270
# Epoch 181/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8287 - loss: 0.5213 - val_accuracy: 0.4583 - val_loss: 1.4275
# Epoch 182/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8687 - loss: 0.4597 - val_accuracy: 0.5000 - val_loss: 1.4359
# Epoch 183/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8810 - loss: 0.4773 - val_accuracy: 0.4583 - val_loss: 1.4336
# Epoch 184/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8674 - loss: 0.4463 - val_accuracy: 0.5417 - val_loss: 1.4155
# Epoch 185/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8743 - loss: 0.4624 - val_accuracy: 0.5417 - val_loss: 1.4239
# Epoch 186/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8587 - loss: 0.4592 - val_accuracy: 0.4583 - val_loss: 1.4414
# Epoch 187/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8637 - loss: 0.4419 - val_accuracy: 0.5000 - val_loss: 1.4430
# Epoch 188/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8587 - loss: 0.4594 - val_accuracy: 0.5000 - val_loss: 1.4345
# Epoch 189/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8710 - loss: 0.4654 - val_accuracy: 0.5000 - val_loss: 1.4545
# Epoch 190/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8753 - loss: 0.4619 - val_accuracy: 0.5000 - val_loss: 1.4404
# Epoch 191/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8097 - loss: 0.5039 - val_accuracy: 0.5000 - val_loss: 1.4338
# Epoch 192/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8637 - loss: 0.4520 - val_accuracy: 0.5000 - val_loss: 1.4431
# Epoch 193/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8637 - loss: 0.4307 - val_accuracy: 0.5000 - val_loss: 1.4562
# Epoch 194/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8337 - loss: 0.4437 - val_accuracy: 0.4583 - val_loss: 1.4645
# Epoch 195/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8487 - loss: 0.4455 - val_accuracy: 0.4583 - val_loss: 1.4652
# Epoch 196/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8470 - loss: 0.4334 - val_accuracy: 0.4583 - val_loss: 1.4489
# Epoch 197/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8743 - loss: 0.4460 - val_accuracy: 0.4583 - val_loss: 1.4514
# Epoch 198/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9066 - loss: 0.4202 - val_accuracy: 0.5000 - val_loss: 1.4713
# Epoch 199/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8576 - loss: 0.4471 - val_accuracy: 0.5000 - val_loss: 1.4627
# Epoch 200/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8453 - loss: 0.4542 - val_accuracy: 0.4583 - val_loss: 1.4698
# Epoch 201/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8626 - loss: 0.4601 - val_accuracy: 0.5000 - val_loss: 1.4934
# Epoch 202/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8953 - loss: 0.4024 - val_accuracy: 0.4583 - val_loss: 1.5353
# Epoch 203/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8680 - loss: 0.4559 - val_accuracy: 0.5000 - val_loss: 1.4931
# Epoch 204/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8976 - loss: 0.4359 - val_accuracy: 0.5000 - val_loss: 1.4879
# Epoch 205/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9066 - loss: 0.3996 - val_accuracy: 0.5417 - val_loss: 1.4696
# Epoch 206/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8226 - loss: 0.4542 - val_accuracy: 0.5000 - val_loss: 1.4957
# Epoch 207/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8760 - loss: 0.4203 - val_accuracy: 0.4583 - val_loss: 1.5068
# Epoch 208/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9099 - loss: 0.4116 - val_accuracy: 0.5000 - val_loss: 1.5089
# Epoch 209/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9149 - loss: 0.3794 - val_accuracy: 0.4583 - val_loss: 1.4894
# Epoch 210/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8583 - loss: 0.4245 - val_accuracy: 0.5000 - val_loss: 1.5115
# Epoch 211/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8916 - loss: 0.4146 - val_accuracy: 0.5000 - val_loss: 1.5025
# Epoch 212/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8899 - loss: 0.3806 - val_accuracy: 0.5000 - val_loss: 1.5142
# Epoch 213/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8683 - loss: 0.4027 - val_accuracy: 0.5000 - val_loss: 1.5239
# Epoch 214/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9122 - loss: 0.4037 - val_accuracy: 0.4583 - val_loss: 1.5225
# Epoch 215/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8816 - loss: 0.4124 - val_accuracy: 0.4583 - val_loss: 1.5423
# Epoch 216/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8656 - loss: 0.4426 - val_accuracy: 0.5000 - val_loss: 1.5392
# Epoch 217/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8833 - loss: 0.3816 - val_accuracy: 0.5000 - val_loss: 1.5255
# Epoch 218/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9156 - loss: 0.3739 - val_accuracy: 0.4583 - val_loss: 1.5335
# Epoch 219/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9022 - loss: 0.3913 - val_accuracy: 0.4583 - val_loss: 1.5314
# Epoch 220/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9183 - loss: 0.3454 - val_accuracy: 0.5000 - val_loss: 1.5211
# Epoch 221/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9183 - loss: 0.3583 - val_accuracy: 0.5000 - val_loss: 1.5444
# Epoch 222/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9106 - loss: 0.3680 - val_accuracy: 0.5417 - val_loss: 1.5365
# Epoch 223/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9049 - loss: 0.3653 - val_accuracy: 0.5000 - val_loss: 1.5260
# Epoch 224/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9106 - loss: 0.3691 - val_accuracy: 0.5000 - val_loss: 1.5273
# Epoch 225/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8816 - loss: 0.3777 - val_accuracy: 0.5000 - val_loss: 1.5395
# Epoch 226/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9339 - loss: 0.3560 - val_accuracy: 0.5417 - val_loss: 1.5545
# Epoch 227/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8916 - loss: 0.3742 - val_accuracy: 0.4583 - val_loss: 1.5500
# Epoch 228/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9279 - loss: 0.3442 - val_accuracy: 0.5000 - val_loss: 1.5631
# Epoch 229/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8872 - loss: 0.3830 - val_accuracy: 0.5000 - val_loss: 1.5742
# Epoch 230/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9145 - loss: 0.3700 - val_accuracy: 0.5000 - val_loss: 1.6123
# Epoch 231/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8952 - loss: 0.3803 - val_accuracy: 0.5000 - val_loss: 1.5957
# Epoch 232/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9235 - loss: 0.3596 - val_accuracy: 0.4583 - val_loss: 1.6005
# Epoch 233/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9402 - loss: 0.3650 - val_accuracy: 0.5000 - val_loss: 1.5907
# Epoch 234/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9056 - loss: 0.3491 - val_accuracy: 0.4583 - val_loss: 1.6001
# Epoch 235/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9385 - loss: 0.3352 - val_accuracy: 0.5000 - val_loss: 1.6180
# Epoch 236/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9452 - loss: 0.3546 - val_accuracy: 0.4583 - val_loss: 1.6079
# Epoch 237/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9418 - loss: 0.3049 - val_accuracy: 0.4583 - val_loss: 1.6166
# Epoch 238/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9302 - loss: 0.3453 - val_accuracy: 0.4583 - val_loss: 1.6251
# Epoch 239/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9162 - loss: 0.3344 - val_accuracy: 0.5000 - val_loss: 1.6464
# Epoch 240/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9052 - loss: 0.3601 - val_accuracy: 0.5000 - val_loss: 1.6266
# Epoch 241/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9179 - loss: 0.3371 - val_accuracy: 0.5000 - val_loss: 1.6287
# Epoch 242/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9295 - loss: 0.3293 - val_accuracy: 0.5000 - val_loss: 1.6744
# Epoch 243/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9341 - loss: 0.3399 - val_accuracy: 0.4583 - val_loss: 1.6403
# Epoch 244/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9302 - loss: 0.3272 - val_accuracy: 0.5000 - val_loss: 1.6549
# Epoch 245/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9002 - loss: 0.3717 - val_accuracy: 0.5000 - val_loss: 1.6823
# Epoch 246/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9341 - loss: 0.3440 - val_accuracy: 0.4583 - val_loss: 1.6926
# Epoch 247/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9281 - loss: 0.3450 - val_accuracy: 0.5000 - val_loss: 1.6763
# Epoch 248/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9475 - loss: 0.3297 - val_accuracy: 0.5000 - val_loss: 1.6797
# Epoch 249/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9631 - loss: 0.3017 - val_accuracy: 0.5000 - val_loss: 1.6924
# Epoch 250/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9591 - loss: 0.3208 - val_accuracy: 0.5000 - val_loss: 1.6963
# Epoch 251/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9714 - loss: 0.2948 - val_accuracy: 0.4583 - val_loss: 1.6978
# Epoch 252/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9341 - loss: 0.3475 - val_accuracy: 0.5000 - val_loss: 1.7188
# Epoch 253/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9341 - loss: 0.3240 - val_accuracy: 0.5000 - val_loss: 1.7081
# Epoch 254/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9391 - loss: 0.3100 - val_accuracy: 0.4583 - val_loss: 1.6967
# Epoch 255/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9648 - loss: 0.3058 - val_accuracy: 0.4583 - val_loss: 1.6701
# Epoch 256/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9325 - loss: 0.3082 - val_accuracy: 0.4583 - val_loss: 1.6938
# Epoch 257/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9564 - loss: 0.2939 - val_accuracy: 0.4583 - val_loss: 1.6926
# Epoch 258/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9564 - loss: 0.3241 - val_accuracy: 0.5000 - val_loss: 1.7023
# Epoch 259/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9614 - loss: 0.2640 - val_accuracy: 0.4583 - val_loss: 1.7144
# Epoch 260/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9531 - loss: 0.2919 - val_accuracy: 0.5000 - val_loss: 1.7237
# Epoch 261/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9581 - loss: 0.2961 - val_accuracy: 0.4583 - val_loss: 1.7431
# Epoch 262/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9381 - loss: 0.3108 - val_accuracy: 0.5000 - val_loss: 1.7389
# Epoch 263/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9531 - loss: 0.3004 - val_accuracy: 0.4583 - val_loss: 1.7372
# Epoch 264/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9431 - loss: 0.2886 - val_accuracy: 0.4583 - val_loss: 1.7446
# Epoch 265/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9614 - loss: 0.2869 - val_accuracy: 0.5000 - val_loss: 1.7290
# Epoch 266/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9621 - loss: 0.2922 - val_accuracy: 0.5000 - val_loss: 1.7353
# Epoch 267/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9671 - loss: 0.2770 - val_accuracy: 0.5000 - val_loss: 1.7607
# Epoch 268/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9821 - loss: 0.2475 - val_accuracy: 0.4583 - val_loss: 1.7795
# Epoch 269/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9764 - loss: 0.2747 - val_accuracy: 0.4583 - val_loss: 1.8012
# Epoch 270/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9771 - loss: 0.2537 - val_accuracy: 0.4583 - val_loss: 1.7859
# Epoch 271/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9714 - loss: 0.2589 - val_accuracy: 0.4583 - val_loss: 1.7772
# Epoch 272/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9664 - loss: 0.2678 - val_accuracy: 0.4583 - val_loss: 1.7808
# Epoch 273/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9714 - loss: 0.2733 - val_accuracy: 0.4583 - val_loss: 1.7935
# Epoch 274/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9731 - loss: 0.2613 - val_accuracy: 0.5000 - val_loss: 1.8200
# Epoch 275/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9854 - loss: 0.2444 - val_accuracy: 0.4583 - val_loss: 1.8003
# Epoch 276/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9621 - loss: 0.2756 - val_accuracy: 0.4583 - val_loss: 1.8239
# Epoch 277/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9521 - loss: 0.2824 - val_accuracy: 0.4583 - val_loss: 1.8290
# Epoch 278/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9671 - loss: 0.2878 - val_accuracy: 0.4583 - val_loss: 1.8149
# Epoch 279/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9714 - loss: 0.2514 - val_accuracy: 0.4167 - val_loss: 1.8229
# Epoch 280/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9531 - loss: 0.2546 - val_accuracy: 0.4583 - val_loss: 1.8276
# Epoch 281/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9671 - loss: 0.2446 - val_accuracy: 0.4583 - val_loss: 1.8480
# Epoch 282/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9771 - loss: 0.2484 - val_accuracy: 0.4583 - val_loss: 1.8703
# Epoch 283/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9804 - loss: 0.2370 - val_accuracy: 0.4583 - val_loss: 1.8639
# Epoch 284/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9771 - loss: 0.2515 - val_accuracy: 0.4583 - val_loss: 1.8576
# Epoch 285/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9671 - loss: 0.2384 - val_accuracy: 0.4583 - val_loss: 1.8524
# Epoch 286/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9671 - loss: 0.2662 - val_accuracy: 0.4583 - val_loss: 1.8800
# Epoch 287/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9854 - loss: 0.2340 - val_accuracy: 0.4167 - val_loss: 1.8860
# Epoch 288/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9944 - loss: 0.2364 - val_accuracy: 0.4167 - val_loss: 1.8518
# Epoch 289/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9771 - loss: 0.2222 - val_accuracy: 0.4583 - val_loss: 1.9013
# Epoch 290/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9671 - loss: 0.2409 - val_accuracy: 0.4583 - val_loss: 1.9259
# Epoch 291/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9854 - loss: 0.2226 - val_accuracy: 0.4167 - val_loss: 1.9028
# Epoch 292/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9854 - loss: 0.2367 - val_accuracy: 0.4583 - val_loss: 1.9046
# Epoch 293/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9771 - loss: 0.2195 - val_accuracy: 0.5000 - val_loss: 1.9383
# Epoch 294/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9671 - loss: 0.2436 - val_accuracy: 0.4583 - val_loss: 1.9523
# Epoch 295/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9704 - loss: 0.2315 - val_accuracy: 0.4583 - val_loss: 1.9332
# Epoch 296/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9721 - loss: 0.2224 - val_accuracy: 0.4583 - val_loss: 1.9288
# Epoch 297/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9704 - loss: 0.2294 - val_accuracy: 0.4583 - val_loss: 1.9587
# Epoch 298/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9944 - loss: 0.2146 - val_accuracy: 0.5000 - val_loss: 1.9182
# Epoch 299/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9704 - loss: 0.2100 - val_accuracy: 0.4583 - val_loss: 1.9469
# Epoch 300/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9821 - loss: 0.2277 - val_accuracy: 0.4583 - val_loss: 1.9617

# %% [markdown]
# ### Discussion

# %% [markdown]
# In the hidden layers, we used the ReLU activation function. ReLU is widely used in neural networks because it helps the model learn nonlinear relationships and is computationally efficient.
#
# In the final layer, we used the softmax activation function because this is a multi-class classification problem. Softmax converts the outputs into probabilities for each class, and the probabilities sum to 1. This allows the model to select the class with the highest probability as the prediction.

# %% [markdown]
# ### Discussion

# %% [markdown]
# Training for 300 epochs may not always be necessary, especially for a relatively small dataset like this one. While more epochs allow the model to learn more patterns from the training data, training for too long can lead to overfitting.
#
# A better approach would be to monitor the validation performance and stop training when the model stops improving. Techniques such as early stopping can help prevent unnecessary training and improve generalization.

# %% [markdown]
# ### Discussion

# %% [markdown]
# The loss function `categorical_crossentropy` was used because this is a multi-class classification problem and the target labels were encoded using one-hot encoding. This loss function measures the difference between the predicted probability distribution and the true distribution of the classes.
#
# The optimizer `sgd` (stochastic gradient descent) was used to update the model weights during training. SGD is a common and simple optimization method that adjusts the weights based on the gradient of the loss function.
#
# However, we might consider using a different optimizer such as `adam`. Adam often converges faster and is more stable during training, especially for neural networks. Using Adam could potentially improve training efficiency and model performance.

# %% [markdown]
# ### Plot Training Curves
#
# Extract the model training history and plot the learning curves (e.g., training vs. validation loss and accuracy) across epochs.

# %%
## plot training and validation curves in a single plot
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.legend()

plt.show()

# %%
# Generate predicted y values
from sklearn.metrics import accuracy_score, classification_report

pred_probs = keras_model.predict(X_test_final)

# Note: Keras predict returns the predicted column index location for classification models
prediction_column_index= np.argmax(pred_probs, axis=1)
labels = pd.Categorical(y_train).categories

# Extract correct prediction labels
prediction_labels = [labels[i] for i in prediction_column_index]

## Show model performance by comparing prediction_labels with true labels
print("Accuracy:", accuracy_score(y_test, prediction_labels))
print(classification_report(y_test, prediction_labels))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Accuracy: 0.5952380952380952
#               precision    recall  f1-score   support
#
#      Average       0.67      0.50      0.57         8
#         High       0.71      0.62      0.67         8
#          Low       0.38      0.38      0.38         8
#    Very High       0.73      0.89      0.80         9
#     Very Low       0.50      0.56      0.53         9
#
#     accuracy                           0.60        42
#    macro avg       0.60      0.59      0.59        42
# weighted avg       0.60      0.60      0.59        42

# %% [markdown]
# ### Regularization: Dropout and Batch Normalization
#
# Implement regularization techniques such as **Dropout** and **Batch Normalization** to improve generalization and observe the change in performance.
#
# > **Note:** Compare training vs. test (or validation) loss and accuracy before and after adding regularization.

# %%
from keras.layers import Dropout

reg_model = Sequential()

reg_model.add(Dense(128, activation='relu', input_shape=(feature_count,)))
reg_model.add(Dropout(0.3))

reg_model.add(Dense(64, activation='relu'))
reg_model.add(Dropout(0.3))

reg_model.add(Dense(32, activation='relu'))

reg_model.add(Dense(5, activation='softmax'))

reg_model.compile(
    loss='categorical_crossentropy',
    optimizer='sgd',
    metrics=['accuracy']
)

reg_model.fit(
    X_train_final,
    y_train_encoded,
    batch_size=20,
    epochs=100,
    validation_split=0.25
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.1526 - loss: 1.6648 - val_accuracy: 0.2083 - val_loss: 1.6346
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2081 - loss: 1.6562 - val_accuracy: 0.2500 - val_loss: 1.6243
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.1936 - loss: 1.6156 - val_accuracy: 0.2500 - val_loss: 1.6143
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.2089 - loss: 1.6429 - val_accuracy: 0.2917 - val_loss: 1.6074
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2368 - loss: 1.6152 - val_accuracy: 0.2500 - val_loss: 1.6000
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.1778 - loss: 1.6226 - val_accuracy: 0.2917 - val_loss: 1.5927
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2577 - loss: 1.5279 - val_accuracy: 0.2917 - val_loss: 1.5850
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2960 - loss: 1.5310 - val_accuracy: 0.2500 - val_loss: 1.5787
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2881 - loss: 1.5520 - val_accuracy: 0.2083 - val_loss: 1.5727
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.2593 - loss: 1.5434 - val_accuracy: 0.3333 - val_loss: 1.5625
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3175 - loss: 1.4999 - val_accuracy: 0.3333 - val_loss: 1.5529
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.2456 - loss: 1.5222 - val_accuracy: 0.3333 - val_loss: 1.5452
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.2912 - loss: 1.5280 - val_accuracy: 0.3333 - val_loss: 1.5392
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4150 - loss: 1.4519 - val_accuracy: 0.3333 - val_loss: 1.5323
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3871 - loss: 1.4454 - val_accuracy: 0.3333 - val_loss: 1.5246
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2981 - loss: 1.4692 - val_accuracy: 0.3333 - val_loss: 1.5167
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3800 - loss: 1.4742 - val_accuracy: 0.3750 - val_loss: 1.5056
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4321 - loss: 1.4162 - val_accuracy: 0.3750 - val_loss: 1.4978
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3894 - loss: 1.4246 - val_accuracy: 0.3750 - val_loss: 1.4916
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4586 - loss: 1.3809 - val_accuracy: 0.3750 - val_loss: 1.4835
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5028 - loss: 1.3058 - val_accuracy: 0.3750 - val_loss: 1.4759
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5126 - loss: 1.2999 - val_accuracy: 0.3750 - val_loss: 1.4689
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4630 - loss: 1.3040 - val_accuracy: 0.4167 - val_loss: 1.4620
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4749 - loss: 1.2894 - val_accuracy: 0.4167 - val_loss: 1.4554
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4157 - loss: 1.2817 - val_accuracy: 0.3750 - val_loss: 1.4473
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5797 - loss: 1.2695 - val_accuracy: 0.3750 - val_loss: 1.4397
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4905 - loss: 1.2797 - val_accuracy: 0.3750 - val_loss: 1.4340
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5620 - loss: 1.2167 - val_accuracy: 0.3750 - val_loss: 1.4280
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5581 - loss: 1.2123 - val_accuracy: 0.3750 - val_loss: 1.4222
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5338 - loss: 1.1562 - val_accuracy: 0.3750 - val_loss: 1.4160
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5341 - loss: 1.1867 - val_accuracy: 0.3750 - val_loss: 1.4101
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4876 - loss: 1.2297 - val_accuracy: 0.4167 - val_loss: 1.4047
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6060 - loss: 1.1041 - val_accuracy: 0.4167 - val_loss: 1.3985
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6335 - loss: 1.1507 - val_accuracy: 0.4167 - val_loss: 1.3931
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4613 - loss: 1.1562 - val_accuracy: 0.4167 - val_loss: 1.3893
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5018 - loss: 1.1435 - val_accuracy: 0.4167 - val_loss: 1.3850
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4322 - loss: 1.2059 - val_accuracy: 0.4167 - val_loss: 1.3840
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4192 - loss: 1.1863 - val_accuracy: 0.3750 - val_loss: 1.3810
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5628 - loss: 1.0466 - val_accuracy: 0.3750 - val_loss: 1.3783
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6070 - loss: 1.0404 - val_accuracy: 0.3333 - val_loss: 1.3760
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5877 - loss: 1.1214 - val_accuracy: 0.3333 - val_loss: 1.3711
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5128 - loss: 1.0829 - val_accuracy: 0.3333 - val_loss: 1.3678
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5464 - loss: 1.0960 - val_accuracy: 0.2917 - val_loss: 1.3610
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5410 - loss: 1.1310 - val_accuracy: 0.2917 - val_loss: 1.3596
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5931 - loss: 1.0506 - val_accuracy: 0.2917 - val_loss: 1.3551
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5172 - loss: 1.0942 - val_accuracy: 0.3333 - val_loss: 1.3526
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4386 - loss: 1.0746 - val_accuracy: 0.3333 - val_loss: 1.3515
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5485 - loss: 1.1195 - val_accuracy: 0.3333 - val_loss: 1.3492
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4828 - loss: 1.0870 - val_accuracy: 0.3333 - val_loss: 1.3449
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4805 - loss: 1.0397 - val_accuracy: 0.3333 - val_loss: 1.3443
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3754 - loss: 1.0732 - val_accuracy: 0.3333 - val_loss: 1.3365
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5347 - loss: 1.0776 - val_accuracy: 0.3750 - val_loss: 1.3327
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5658 - loss: 1.0254 - val_accuracy: 0.3750 - val_loss: 1.3293
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5001 - loss: 1.0602 - val_accuracy: 0.4167 - val_loss: 1.3231
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5068 - loss: 1.0468 - val_accuracy: 0.4167 - val_loss: 1.3261
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4330 - loss: 1.0668 - val_accuracy: 0.4167 - val_loss: 1.3236
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4865 - loss: 1.1071 - val_accuracy: 0.4167 - val_loss: 1.3288
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5199 - loss: 1.0371 - val_accuracy: 0.4167 - val_loss: 1.3194
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4918 - loss: 1.1106 - val_accuracy: 0.4167 - val_loss: 1.3197
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5700 - loss: 1.0116 - val_accuracy: 0.3750 - val_loss: 1.3238
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5587 - loss: 0.9867 - val_accuracy: 0.4167 - val_loss: 1.3198
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4888 - loss: 1.0153 - val_accuracy: 0.4167 - val_loss: 1.3128
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5022 - loss: 1.0243 - val_accuracy: 0.4167 - val_loss: 1.3113
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4997 - loss: 0.9938 - val_accuracy: 0.4167 - val_loss: 1.3113
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4722 - loss: 1.0364 - val_accuracy: 0.4167 - val_loss: 1.3048
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4815 - loss: 0.9593 - val_accuracy: 0.4167 - val_loss: 1.3047
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6619 - loss: 0.9478 - val_accuracy: 0.4167 - val_loss: 1.2999
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5162 - loss: 1.0060 - val_accuracy: 0.4167 - val_loss: 1.3039
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6433 - loss: 0.9350 - val_accuracy: 0.4167 - val_loss: 1.3005
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5481 - loss: 0.9519 - val_accuracy: 0.4167 - val_loss: 1.2962
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6133 - loss: 1.0095 - val_accuracy: 0.4167 - val_loss: 1.2918
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5883 - loss: 1.0006 - val_accuracy: 0.4167 - val_loss: 1.2881
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5504 - loss: 0.9676 - val_accuracy: 0.4167 - val_loss: 1.2867
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5074 - loss: 0.9823 - val_accuracy: 0.4167 - val_loss: 1.2859
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5910 - loss: 0.9294 - val_accuracy: 0.4167 - val_loss: 1.2844
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7073 - loss: 0.8601 - val_accuracy: 0.4167 - val_loss: 1.2813
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4762 - loss: 1.0420 - val_accuracy: 0.4167 - val_loss: 1.2834
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.4985 - loss: 0.9641 - val_accuracy: 0.4167 - val_loss: 1.2845
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4712 - loss: 1.0114 - val_accuracy: 0.4167 - val_loss: 1.2806
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4938 - loss: 1.0220 - val_accuracy: 0.4167 - val_loss: 1.2810
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5839 - loss: 0.9583 - val_accuracy: 0.4167 - val_loss: 1.2736
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6500 - loss: 0.8923 - val_accuracy: 0.4167 - val_loss: 1.2677
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6012 - loss: 0.8927 - val_accuracy: 0.4167 - val_loss: 1.2658
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5414 - loss: 0.9448 - val_accuracy: 0.4167 - val_loss: 1.2667
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6050 - loss: 0.9801 - val_accuracy: 0.4167 - val_loss: 1.2666
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6479 - loss: 0.8517 - val_accuracy: 0.4167 - val_loss: 1.2673
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5833 - loss: 0.9811 - val_accuracy: 0.4167 - val_loss: 1.2694
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6146 - loss: 0.9476 - val_accuracy: 0.4167 - val_loss: 1.2614
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6548 - loss: 0.8951 - val_accuracy: 0.4167 - val_loss: 1.2540
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6160 - loss: 0.9191 - val_accuracy: 0.4167 - val_loss: 1.2481
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6493 - loss: 0.8700 - val_accuracy: 0.4167 - val_loss: 1.2396
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6100 - loss: 0.8798 - val_accuracy: 0.4167 - val_loss: 1.2326
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6669 - loss: 0.8572 - val_accuracy: 0.4167 - val_loss: 1.2314
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6442 - loss: 0.9033 - val_accuracy: 0.4583 - val_loss: 1.2288
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5716 - loss: 0.8723 - val_accuracy: 0.4583 - val_loss: 1.2289
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6302 - loss: 0.8630 - val_accuracy: 0.4583 - val_loss: 1.2239
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6269 - loss: 0.8962 - val_accuracy: 0.4583 - val_loss: 1.2227
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6242 - loss: 0.8551 - val_accuracy: 0.4583 - val_loss: 1.2224
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5458 - loss: 0.9040 - val_accuracy: 0.4583 - val_loss: 1.2175
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6069 - loss: 0.9048 - val_accuracy: 0.4583 - val_loss: 1.2248

# %%
# Generate predictions for regularized models
reg_pred_probs = reg_model.predict(X_test_final)
reg_prediction_index = np.argmax(reg_pred_probs, axis=1)

labels = pd.Categorical(y_train).categories
reg_prediction_labels = [labels[i] for i in reg_prediction_index]

# Print the test set performance of the regularized model
print("--- [After Regularization] Regularized MLP Performance ---")
print("Accuracy:", accuracy_score(y_test, reg_prediction_labels))
print(classification_report(y_test, reg_prediction_labels))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# --- [After Regularization] Regularized MLP Performance ---
# Accuracy: 0.5238095238095238
#               precision    recall  f1-score   support
#
#      Average       1.00      0.12      0.22         8
#         High       0.50      0.75      0.60         8
#          Low       0.38      0.38      0.38         8
#    Very High       0.89      0.89      0.89         9
#     Very Low       0.33      0.44      0.38         9
#
#     accuracy                           0.52        42
#    macro avg       0.62      0.52      0.49        42
# weighted avg       0.62      0.52      0.50        42

# %%
# Extract the final metrics for both models (using the results from the last iteration)

reg_history = reg_model.fit(
    X_train_final,
    y_train_encoded,
    batch_size=20,
    epochs=100,
    validation_split=0.25
)

comparison_data = {
    "Metric": ["Train Accuracy", "Val Accuracy", "Train Loss", "Val Loss"],
    "Baseline MLP": [
        history.history['accuracy'][-1],
        history.history['val_accuracy'][-1],
        history.history['loss'][-1],
        history.history['val_loss'][-1]
    ],
    "Regularized MLP": [
        reg_history.history['accuracy'][-1],
        reg_history.history['val_accuracy'][-1],
        reg_history.history['loss'][-1],
        reg_history.history['val_loss'][-1]
    ]
}

df_comparison = pd.DataFrame(comparison_data)
print("\n--- Summary: Training vs. Validation Comparison ---")
print(df_comparison.to_string(index=False))
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9804 - loss: 0.2407 - val_accuracy: 0.4167 - val_loss: 2.0842
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9095 - loss: 0.2355 - val_accuracy: 0.4167 - val_loss: 2.0940
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9468 - loss: 0.2145 - val_accuracy: 0.4167 - val_loss: 2.0945
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9052 - loss: 0.3389 - val_accuracy: 0.4167 - val_loss: 2.0894
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9591 - loss: 0.1814 - val_accuracy: 0.4167 - val_loss: 2.0477
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9335 - loss: 0.2685 - val_accuracy: 0.4167 - val_loss: 2.0407
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8833 - loss: 0.2576 - val_accuracy: 0.4167 - val_loss: 2.0396
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9391 - loss: 0.2451 - val_accuracy: 0.4167 - val_loss: 2.0561
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8922 - loss: 0.2436 - val_accuracy: 0.4167 - val_loss: 2.0665
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9764 - loss: 0.1953 - val_accuracy: 0.4167 - val_loss: 2.0816
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9625 - loss: 0.1983 - val_accuracy: 0.4167 - val_loss: 2.0899
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9122 - loss: 0.2630 - val_accuracy: 0.4167 - val_loss: 2.1184
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8543 - loss: 0.3076 - val_accuracy: 0.4167 - val_loss: 2.1166
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9106 - loss: 0.2709 - val_accuracy: 0.4167 - val_loss: 2.1119
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9202 - loss: 0.2925 - val_accuracy: 0.4167 - val_loss: 2.1011
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8822 - loss: 0.3170 - val_accuracy: 0.4167 - val_loss: 2.0913
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9771 - loss: 0.1678 - val_accuracy: 0.4167 - val_loss: 2.1042
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9295 - loss: 0.2392 - val_accuracy: 0.4167 - val_loss: 2.1183
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9129 - loss: 0.2565 - val_accuracy: 0.4167 - val_loss: 2.1271
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8912 - loss: 0.2252 - val_accuracy: 0.4167 - val_loss: 2.1431
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8576 - loss: 0.3393 - val_accuracy: 0.4167 - val_loss: 2.1156
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9289 - loss: 0.2142 - val_accuracy: 0.4167 - val_loss: 2.0778
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9318 - loss: 0.1814 - val_accuracy: 0.4167 - val_loss: 2.0914
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9381 - loss: 0.2779 - val_accuracy: 0.4167 - val_loss: 2.1183
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9431 - loss: 0.2302 - val_accuracy: 0.4167 - val_loss: 2.1029
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9771 - loss: 0.1673 - val_accuracy: 0.4167 - val_loss: 2.1096
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8972 - loss: 0.2763 - val_accuracy: 0.4167 - val_loss: 2.1208
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9102 - loss: 0.2431 - val_accuracy: 0.4167 - val_loss: 2.1451
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9162 - loss: 0.2251 - val_accuracy: 0.4167 - val_loss: 2.1374
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9531 - loss: 0.2012 - val_accuracy: 0.4167 - val_loss: 2.1380
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9391 - loss: 0.2045 - val_accuracy: 0.4167 - val_loss: 2.1401
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9441 - loss: 0.2146 - val_accuracy: 0.4167 - val_loss: 2.1371
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9804 - loss: 0.2304 - val_accuracy: 0.4167 - val_loss: 2.1750
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9671 - loss: 0.1840 - val_accuracy: 0.4167 - val_loss: 2.1899
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9804 - loss: 0.1764 - val_accuracy: 0.4167 - val_loss: 2.1564
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9195 - loss: 0.2407 - val_accuracy: 0.4167 - val_loss: 2.1524
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9771 - loss: 0.2068 - val_accuracy: 0.4167 - val_loss: 2.1356
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9402 - loss: 0.2462 - val_accuracy: 0.4167 - val_loss: 2.1540
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9245 - loss: 0.1989 - val_accuracy: 0.4167 - val_loss: 2.1710
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9681 - loss: 0.1732 - val_accuracy: 0.4167 - val_loss: 2.1831
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8949 - loss: 0.3154 - val_accuracy: 0.4167 - val_loss: 2.1576
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9285 - loss: 0.1991 - val_accuracy: 0.4167 - val_loss: 2.1804
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9285 - loss: 0.2475 - val_accuracy: 0.4167 - val_loss: 2.1614
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9491 - loss: 0.1914 - val_accuracy: 0.4167 - val_loss: 2.1542
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9748 - loss: 0.1711 - val_accuracy: 0.4167 - val_loss: 2.1455
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8230 - loss: 0.3346 - val_accuracy: 0.4167 - val_loss: 2.1503
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9541 - loss: 0.2012 - val_accuracy: 0.4167 - val_loss: 2.1599
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9106 - loss: 0.2367 - val_accuracy: 0.4167 - val_loss: 2.1413
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9352 - loss: 0.2280 - val_accuracy: 0.4167 - val_loss: 2.1495
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8570 - loss: 0.2896 - val_accuracy: 0.4167 - val_loss: 2.1711
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9804 - loss: 0.1488 - val_accuracy: 0.4167 - val_loss: 2.1967
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9531 - loss: 0.2165 - val_accuracy: 0.4167 - val_loss: 2.2047
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9798 - loss: 0.1670 - val_accuracy: 0.4167 - val_loss: 2.1747
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9368 - loss: 0.2328 - val_accuracy: 0.4167 - val_loss: 2.2131
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9464 - loss: 0.2202 - val_accuracy: 0.4167 - val_loss: 2.2140
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9356 - loss: 0.2121 - val_accuracy: 0.4167 - val_loss: 2.2202
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9235 - loss: 0.2536 - val_accuracy: 0.4167 - val_loss: 2.1895
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9262 - loss: 0.2448 - val_accuracy: 0.4167 - val_loss: 2.1770
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9066 - loss: 0.2047 - val_accuracy: 0.4583 - val_loss: 2.1963
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9412 - loss: 0.1822 - val_accuracy: 0.4583 - val_loss: 2.2136
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9122 - loss: 0.2658 - val_accuracy: 0.4583 - val_loss: 2.2019
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9291 - loss: 0.2461 - val_accuracy: 0.4583 - val_loss: 2.2200
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8766 - loss: 0.3334 - val_accuracy: 0.4583 - val_loss: 2.1888
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9425 - loss: 0.1888 - val_accuracy: 0.4583 - val_loss: 2.1818
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9356 - loss: 0.2197 - val_accuracy: 0.4583 - val_loss: 2.2020
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9391 - loss: 0.1839 - val_accuracy: 0.4583 - val_loss: 2.2128
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9441 - loss: 0.2183 - val_accuracy: 0.4583 - val_loss: 2.2279
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9625 - loss: 0.2103 - val_accuracy: 0.4583 - val_loss: 2.2355
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9671 - loss: 0.1836 - val_accuracy: 0.4583 - val_loss: 2.2400
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9381 - loss: 0.2157 - val_accuracy: 0.4583 - val_loss: 2.2522
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8780 - loss: 0.2638 - val_accuracy: 0.4583 - val_loss: 2.2355
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8989 - loss: 0.2602 - val_accuracy: 0.4583 - val_loss: 2.2317
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9562 - loss: 0.2235 - val_accuracy: 0.4583 - val_loss: 2.2450
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9302 - loss: 0.1977 - val_accuracy: 0.4583 - val_loss: 2.2145
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9508 - loss: 0.2098 - val_accuracy: 0.4583 - val_loss: 2.2265
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8822 - loss: 0.2357 - val_accuracy: 0.4583 - val_loss: 2.2164
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9475 - loss: 0.2062 - val_accuracy: 0.4583 - val_loss: 2.2420
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9760 - loss: 0.1702 - val_accuracy: 0.4583 - val_loss: 2.2491
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9245 - loss: 0.2558 - val_accuracy: 0.4583 - val_loss: 2.2507
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8845 - loss: 0.2205 - val_accuracy: 0.4583 - val_loss: 2.2763
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9085 - loss: 0.2586 - val_accuracy: 0.4583 - val_loss: 2.2457
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8443 - loss: 0.3431 - val_accuracy: 0.4583 - val_loss: 2.2221
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9475 - loss: 0.2474 - val_accuracy: 0.4583 - val_loss: 2.2430
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9185 - loss: 0.2316 - val_accuracy: 0.4583 - val_loss: 2.2407
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8872 - loss: 0.2628 - val_accuracy: 0.4583 - val_loss: 2.2411
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9944 - loss: 0.1638 - val_accuracy: 0.4583 - val_loss: 2.2506
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9285 - loss: 0.2435 - val_accuracy: 0.4583 - val_loss: 2.2639
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9502 - loss: 0.1895 - val_accuracy: 0.4583 - val_loss: 2.2764
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9621 - loss: 0.2134 - val_accuracy: 0.4583 - val_loss: 2.2959
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9285 - loss: 0.1777 - val_accuracy: 0.4583 - val_loss: 2.2923
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9052 - loss: 0.2775 - val_accuracy: 0.4583 - val_loss: 2.2812
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8766 - loss: 0.2641 - val_accuracy: 0.4583 - val_loss: 2.2715
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9581 - loss: 0.2297 - val_accuracy: 0.4583 - val_loss: 2.2767
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9352 - loss: 0.1862 - val_accuracy: 0.4583 - val_loss: 2.2858
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9291 - loss: 0.2090 - val_accuracy: 0.4583 - val_loss: 2.2771
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9408 - loss: 0.2070 - val_accuracy: 0.4583 - val_loss: 2.2658
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9235 - loss: 0.1996 - val_accuracy: 0.4583 - val_loss: 2.2571
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9235 - loss: 0.1983 - val_accuracy: 0.4583 - val_loss: 2.2603
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9521 - loss: 0.1402 - val_accuracy: 0.4583 - val_loss: 2.2834
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9714 - loss: 0.1707 - val_accuracy: 0.4583 - val_loss: 2.3196
#
# --- Summary: Training vs. Validation Comparison ---
#         Metric  Baseline MLP  Regularized MLP
# Train Accuracy      0.971831         0.957747
#   Val Accuracy      0.458333         0.458333
#     Train Loss      0.222725         0.167735
#       Val Loss      1.961683         2.319616

# %% [markdown]
# Accuracy Stability: By implementing Dropout (0.3), the training accuracy slightly decreased from 97.18\% to 95.77\%. While the validation accuracy remained identical at 45.83\% due to the extremely small sample size ($n \approx 24$ in the validation set), the reduction in training performance indicates a curbing of the model's tendency to perfectly memorize the training data.Loss
#
# Volatility in Micro-Datasets: We observe an increase in Val Loss (from 1.96 to 2.32). In the context of a 95-sample dataset, this is a common phenomenon where the stochastic nature of Dropout introduces feature noise" that the model's limited weights struggle to balance, leading to less confident predictions on the validation set.
#
# Generalization Conclusion: These results empirically demonstrate the difficulty of training deep learning architectures on small-scale tabular data. While the Regularized MLP attempts to prevent over-reliance on specific nodes, the Random Forest remains our primary choice for this project due to its inherent robustness and significantly lower generalization gap.

# %% [markdown]
# ### Activation Function Experimentation
#
# Experiment with different activation functions — **ReLU**, **LeakyReLU**, **Tanh**, and **Sigmoid** — and compare their impact on model performance.

# %%
from keras.layers import LeakyReLU

act_model = Sequential()

act_model.add(Dense(128, input_shape=(feature_count,)))
act_model.add(LeakyReLU())

act_model.add(Dense(64))
act_model.add(LeakyReLU())

act_model.add(Dense(32))
act_model.add(LeakyReLU())

act_model.add(Dense(5, activation='softmax'))

act_model.compile(
    loss='categorical_crossentropy',
    optimizer='sgd',
    metrics=['accuracy']
)

act_model.fit(
    X_train_final,
    y_train_encoded,
    batch_size=20,
    epochs=100,
    validation_split=0.25
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.2141 - loss: 1.7048 - val_accuracy: 0.2083 - val_loss: 1.6180
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2816 - loss: 1.6638 - val_accuracy: 0.2083 - val_loss: 1.5930
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3056 - loss: 1.5813 - val_accuracy: 0.1667 - val_loss: 1.5713
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3456 - loss: 1.5093 - val_accuracy: 0.1667 - val_loss: 1.5525
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2962 - loss: 1.5388 - val_accuracy: 0.0833 - val_loss: 1.5374
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3056 - loss: 1.4702 - val_accuracy: 0.0833 - val_loss: 1.5265
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3339 - loss: 1.4232 - val_accuracy: 0.1250 - val_loss: 1.5159
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3969 - loss: 1.3429 - val_accuracy: 0.1250 - val_loss: 1.5048
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3269 - loss: 1.3495 - val_accuracy: 0.1250 - val_loss: 1.4948
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3042 - loss: 1.3448 - val_accuracy: 0.0833 - val_loss: 1.4868
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3702 - loss: 1.2874 - val_accuracy: 0.0833 - val_loss: 1.4779
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2919 - loss: 1.2725 - val_accuracy: 0.0833 - val_loss: 1.4696
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4111 - loss: 1.2273 - val_accuracy: 0.1250 - val_loss: 1.4622
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4696 - loss: 1.2185 - val_accuracy: 0.1667 - val_loss: 1.4564
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4457 - loss: 1.1980 - val_accuracy: 0.2083 - val_loss: 1.4506
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4736 - loss: 1.1908 - val_accuracy: 0.2083 - val_loss: 1.4455
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4609 - loss: 1.1998 - val_accuracy: 0.2083 - val_loss: 1.4416
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4715 - loss: 1.1759 - val_accuracy: 0.2083 - val_loss: 1.4353
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4772 - loss: 1.1459 - val_accuracy: 0.2500 - val_loss: 1.4288
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5145 - loss: 1.1530 - val_accuracy: 0.2083 - val_loss: 1.4245
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5688 - loss: 1.0537 - val_accuracy: 0.2500 - val_loss: 1.4203
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5022 - loss: 1.0648 - val_accuracy: 0.2083 - val_loss: 1.4177
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4978 - loss: 1.1092 - val_accuracy: 0.2083 - val_loss: 1.4132
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5078 - loss: 1.0726 - val_accuracy: 0.2083 - val_loss: 1.4089
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5245 - loss: 1.0560 - val_accuracy: 0.2083 - val_loss: 1.4071
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5401 - loss: 1.0673 - val_accuracy: 0.2083 - val_loss: 1.4025
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5174 - loss: 1.0592 - val_accuracy: 0.2500 - val_loss: 1.3974
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4915 - loss: 1.0195 - val_accuracy: 0.2500 - val_loss: 1.3929
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5318 - loss: 1.0284 - val_accuracy: 0.2500 - val_loss: 1.3930
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5255 - loss: 0.9870 - val_accuracy: 0.2500 - val_loss: 1.3913
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5324 - loss: 1.0025 - val_accuracy: 0.2500 - val_loss: 1.3865
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5658 - loss: 0.9996 - val_accuracy: 0.2500 - val_loss: 1.3842
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5464 - loss: 1.0102 - val_accuracy: 0.2500 - val_loss: 1.3833
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5804 - loss: 1.0118 - val_accuracy: 0.2500 - val_loss: 1.3827
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5933 - loss: 0.9921 - val_accuracy: 0.2500 - val_loss: 1.3809
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5483 - loss: 1.0501 - val_accuracy: 0.2500 - val_loss: 1.3784
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5887 - loss: 0.9126 - val_accuracy: 0.2500 - val_loss: 1.3764
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5816 - loss: 0.9685 - val_accuracy: 0.2500 - val_loss: 1.3739
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6077 - loss: 0.9511 - val_accuracy: 0.2500 - val_loss: 1.3728
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5816 - loss: 0.9618 - val_accuracy: 0.2500 - val_loss: 1.3717
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5766 - loss: 0.9518 - val_accuracy: 0.2500 - val_loss: 1.3713
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5800 - loss: 0.9559 - val_accuracy: 0.2500 - val_loss: 1.3680
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5750 - loss: 0.9591 - val_accuracy: 0.2500 - val_loss: 1.3642
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5933 - loss: 0.9482 - val_accuracy: 0.2083 - val_loss: 1.3608
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5400 - loss: 0.9870 - val_accuracy: 0.1667 - val_loss: 1.3610
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5637 - loss: 0.9487 - val_accuracy: 0.1667 - val_loss: 1.3594
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5660 - loss: 0.9227 - val_accuracy: 0.1667 - val_loss: 1.3590
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5320 - loss: 0.9553 - val_accuracy: 0.2083 - val_loss: 1.3565
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5800 - loss: 0.9278 - val_accuracy: 0.1667 - val_loss: 1.3556
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5281 - loss: 0.8988 - val_accuracy: 0.2083 - val_loss: 1.3545
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5887 - loss: 0.8857 - val_accuracy: 0.2083 - val_loss: 1.3506
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5570 - loss: 0.8653 - val_accuracy: 0.2500 - val_loss: 1.3467
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5910 - loss: 0.8872 - val_accuracy: 0.2500 - val_loss: 1.3447
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5616 - loss: 0.9051 - val_accuracy: 0.2917 - val_loss: 1.3413
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6043 - loss: 0.8957 - val_accuracy: 0.2917 - val_loss: 1.3409
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5816 - loss: 0.8673 - val_accuracy: 0.2917 - val_loss: 1.3394
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6389 - loss: 0.8530 - val_accuracy: 0.2917 - val_loss: 1.3350
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6250 - loss: 0.8473 - val_accuracy: 0.2917 - val_loss: 1.3373
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6127 - loss: 0.8339 - val_accuracy: 0.2500 - val_loss: 1.3326
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5760 - loss: 0.8788 - val_accuracy: 0.2917 - val_loss: 1.3291
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5877 - loss: 0.8735 - val_accuracy: 0.2917 - val_loss: 1.3269
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6289 - loss: 0.8728 - val_accuracy: 0.2500 - val_loss: 1.3250
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5916 - loss: 0.8266 - val_accuracy: 0.2917 - val_loss: 1.3251
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5823 - loss: 0.8630 - val_accuracy: 0.2500 - val_loss: 1.3223
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6135 - loss: 0.8475 - val_accuracy: 0.2500 - val_loss: 1.3211
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6685 - loss: 0.8151 - val_accuracy: 0.2917 - val_loss: 1.3199
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6139 - loss: 0.8630 - val_accuracy: 0.2917 - val_loss: 1.3201
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6329 - loss: 0.8304 - val_accuracy: 0.3333 - val_loss: 1.3192
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6046 - loss: 0.8657 - val_accuracy: 0.3333 - val_loss: 1.3194
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6389 - loss: 0.8265 - val_accuracy: 0.3333 - val_loss: 1.3168
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6123 - loss: 0.8706 - val_accuracy: 0.3333 - val_loss: 1.3196
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5983 - loss: 0.8212 - val_accuracy: 0.3333 - val_loss: 1.3140
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5783 - loss: 0.8581 - val_accuracy: 0.3333 - val_loss: 1.3130
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6429 - loss: 0.8121 - val_accuracy: 0.3333 - val_loss: 1.3107
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5733 - loss: 0.8148 - val_accuracy: 0.3333 - val_loss: 1.3094
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6089 - loss: 0.7827 - val_accuracy: 0.3333 - val_loss: 1.3088
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5733 - loss: 0.8289 - val_accuracy: 0.3333 - val_loss: 1.3100
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6116 - loss: 0.7824 - val_accuracy: 0.3333 - val_loss: 1.3077
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6033 - loss: 0.7951 - val_accuracy: 0.3333 - val_loss: 1.3101
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6473 - loss: 0.7732 - val_accuracy: 0.3333 - val_loss: 1.3091
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6506 - loss: 0.7771 - val_accuracy: 0.3333 - val_loss: 1.3062
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6423 - loss: 0.7773 - val_accuracy: 0.3333 - val_loss: 1.3048
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5816 - loss: 0.8208 - val_accuracy: 0.3750 - val_loss: 1.3047
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6173 - loss: 0.7959 - val_accuracy: 0.3750 - val_loss: 1.3043
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5956 - loss: 0.8058 - val_accuracy: 0.3750 - val_loss: 1.3026
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.6056 - loss: 0.8228 - val_accuracy: 0.3750 - val_loss: 1.3055
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6656 - loss: 0.7560 - val_accuracy: 0.3333 - val_loss: 1.3015
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.6339 - loss: 0.7681 - val_accuracy: 0.3750 - val_loss: 1.3034
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6306 - loss: 0.8028 - val_accuracy: 0.3750 - val_loss: 1.3052
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6369 - loss: 0.7886 - val_accuracy: 0.3750 - val_loss: 1.3017
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6646 - loss: 0.7694 - val_accuracy: 0.3750 - val_loss: 1.3035
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.6219 - loss: 0.7787 - val_accuracy: 0.3750 - val_loss: 1.2983
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.6435 - loss: 0.7669 - val_accuracy: 0.4167 - val_loss: 1.2961
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.6529 - loss: 0.7387 - val_accuracy: 0.4167 - val_loss: 1.2924
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6046 - loss: 0.7791 - val_accuracy: 0.4167 - val_loss: 1.2936
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6129 - loss: 0.7474 - val_accuracy: 0.4167 - val_loss: 1.2901
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6562 - loss: 0.7275 - val_accuracy: 0.4167 - val_loss: 1.2889
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6352 - loss: 0.7606 - val_accuracy: 0.4167 - val_loss: 1.2886
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6102 - loss: 0.7749 - val_accuracy: 0.4167 - val_loss: 1.2891
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.6635 - loss: 0.7352 - val_accuracy: 0.4167 - val_loss: 1.2887

# %%
from keras.layers import LeakyReLU, Activation

# Define experimental parameters
act_functions = ['relu', 'leaky_relu', 'tanh', 'sigmoid']
comparison_results = []

for act in act_functions:
    m = Sequential()
    m.add(Dense(128, input_shape=(feature_count,)))
    if act == 'leaky_relu': m.add(LeakyReLU())
    else: m.add(Activation(act))

    m.add(Dense(64))
    if act == 'leaky_relu': m.add(LeakyReLU())
    else: m.add(Activation(act))

    # Align to Keras model
    m.add(Dense(64))
    if act == 'leaky_relu': m.add(LeakyReLU())
    else: m.add(Activation(act))

    m.add(Dense(32))
    if act == 'leaky_relu': m.add(LeakyReLU())
    else: m.add(Activation(act))

    m.add(Dense(5, activation='softmax'))

    m.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

    # Train model
    h = m.fit(X_train_final, y_train_encoded, epochs=100, batch_size=20, verbose=0, validation_split=0.25)

    comparison_results.append({
        "Activation": act.upper(),
        "Final Train Acc": h.history['accuracy'][-1],
        "Final Val Acc": h.history['val_accuracy'][-1]
    })

# Print comparison form
df_act_comp = pd.DataFrame(comparison_results)
print("--- Activation Function Performance Comparison ---")
print(df_act_comp.to_string(index=False))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# --- Activation Function Performance Comparison ---
# Activation  Final Train Acc  Final Val Acc
#       RELU         0.802817       0.458333
# LEAKY_RELU         0.774648       0.500000
#       TANH         0.859155       0.458333
#    SIGMOID         0.225352       0.125000

# %% [markdown]
# To fulfill the requirement of comparing different activation functions, we cloned the architecture of our baseline MLP (128-64-64-32) and re-trained it four times, varying only the activation function (`ReLU`, `LeakyReLU`, `Tanh`, and `Sigmoid`) while keeping all other hyperparameters (optimizer, epochs, batch size) constant.
#
# **Tanh is the Winner:** In this specific experiment, Tanh outperformed the others. Its zero-centered output likely helped the model converge more effectively on our small, normalized dataset, achieving the highest validation accuracy (50\%).
#
# **LeakyReLU vs. ReLU:** While ReLU showed a decent training score, its validation score dropped significantly (25\%), suggesting instability. LeakyReLU provided much better generalization (45.83\%) by allowing a small gradient for negative values.
#
# **Sigmoid Failure:** Sigmoid performed the worst (12.5\% Val Acc), confirming it is unsuitable for deeper hidden layers due to the vanishing gradient problem.
#
# **Final Decision:** While Tanh showed the best raw numbers here, we prioritize LeakyReLU/ReLU for final architectures due to their robustness in preventing gradient saturation across different feature sets.

# %% [markdown]
# ---
#
# ## 8. Explainability – SHAP Feature Importance
#
# To better understand the model's predictions, we will use **SHAP (SHapley Additive exPlanations)** to analyze feature importance.
#
# **How SHAP works:**
#
# - SHAP assigns each feature a contribution score for every prediction.
# - It uses Shapley values (from cooperative game theory) to fairly distribute importance across features.
#
# We will apply SHAP to visualize and interpret the model's feature contributions.

# %%
import shap

# Extract raw feature names from the fitted ColumnTransformer
raw_feature_names = preprocess.get_feature_names_out()

# Clean up the names by removing the pipeline prefixes (e.g., 'num__' or 'cat__')
# This makes the final SHAP plot look much cleaner and professional
clean_feature_names = [name.split('__')[-1] for name in raw_feature_names]

# Convert the processed numpy array back to a DataFrame with the actual feature names
X_test_df = pd.DataFrame(X_test_final, columns=clean_feature_names)

# Initialize SHAP explainer using the named DataFrame
# (Passing X_test_df instead of X_test_final ensures SHAP learns the column names)
explainer = shap.Explainer(model_2, X_test_df)

# Compute SHAP values for X_test
# This step generates Shapley values, which explain how each feature contributes to predictions
shap_values = explainer(X_test_df)

# Generate SHAP summary plot
# This plot will show which features have the most impact on predictions
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X_test_df, show=False)
plt.title("SHAP Feature Importance: Random Forest", fontsize=14, fontweight='bold', pad=20)
plt.show()
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.12/dist-packages (0.50.0)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from shap) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from shap) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.12/dist-packages (from shap) (4.67.3)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.12/dist-packages (from shap) (26.0)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.12/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from shap) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from shap) (4.15.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2025.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->shap) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->shap) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)

# %% [markdown]
# ### Experimentation

# %%
# Extra Experimentation: SHAP for Neural Network

# Create a wrapper function for the MLP model after regulation prediction
# SHAP KernelExplainer needs a function that takes numpy arrays and returns predictions
def keras_predict(X):
    return reg_model.predict(X, verbose=0)

# Use a summarized background dataset to speed up computation
# We use shap.kmeans to summarize the training set into 10 representative background samples
background = shap.kmeans(X_train_final, 10)

# Initialize the KernelExplainer for our Neural Network
nn_explainer = shap.KernelExplainer(keras_predict, background)

# Calculate SHAP values for the test set
# (This might take a few seconds as it perturbs the inputs to see how the NN reacts)
shap_values_nn = nn_explainer.shap_values(X_test_final)

# Plot the SHAP summary for the Neural Network
plt.figure(figsize=(10, 6))
# Note: For multi-class Keras models, shap_values_nn is a list.
# We visualize the mean absolute SHAP values across all classes using a bar plot.
shap.summary_plot(shap_values_nn, X_test_df, plot_type="bar", show=False)
plt.title("SHAP Feature Importance: Neural Network (MLP)", fontsize=14, fontweight='bold', pad=20)
plt.show()
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]

# %% [markdown]
# Deep learning models are often considered "black boxes" due to their complexity. Use SHAP to explain your model's predictions.
#
# After applying SHAP, discuss:
#
# - Does it provide a clear and sufficient explanation of how the model makes decisions?
# - How easy or difficult is it to justify your model's predictions using this technique?

# %% [markdown]
# ### Explainability: SHAP Analysis (Random Forest vs. MLP)
#
# **1. Does it provide a clear and sufficient explanation of how the model makes decisions?**
#
# Yes, SHAP completely demystifies the "black box" by revealing a profound divergence in how our two models understand the drivers of global happiness. By comparing the feature rankings and the magnitude of the SHAP values (x-axis), we observe two distinct, yet complementary, decision-making paradigms:
#
# * **The Random Forest (Balanced Sociological Rules):** The RF distributes its feature importance evenly, capping the SHAP values around **0.17**. It ranks `social_support`, `gdp_per_capita`, and our engineered `gdp_social_interaction` as the top three. It acts pragmatically, proving that material wealth combined with strong social safety nets forms the most robust, generalizable rule for predicting happiness.
# * **The Neural Network (Economic Baseline + Institutional Nuance):** The MLP relies extremely heavily on `gdp_per_capita` (with a massive SHAP magnitude of **~0.45**), acting initially as an economic determinist. However, its true value lies in the secondary features. Unlike the RF, the MLP highly prioritizes institutional and developmental signals—such as `expected_years_of_schooling` and `perceptions_of_corruption`. This shows the neural network is using its hidden layers to synthesize non-linear, systemic health indicators that the decision tree largely ignored.
#
# **2. How easy or difficult is it to justify your model's predictions using this technique?**
#
# * Justifying the Random Forest's predictions is highly intuitive for immediate policy-making. Its logic aligns directly with mainstream socio-economic consensus: secure the social support and economic baseline first.
# * Justifying the MLP's predictions is more difficult due to its extreme GDP weighting, but it provides crucial diagnostic value. It forces us to acknowledge that in a complex deep-learning feature space, soft institutional factors (like trust in government and long-term education) play a vital non-linear role in shaping a country's ultimate happiness classification.
#
# *Due to the stochastic nature of KernelExplainer and K-means background summarization, slight variations in feature rankings may occur across runs, though primary drivers remain consistent.*
#
# ###Conclusion:
# We think SHAP proves that neither model is "wrong"—they simply offer different lenses. The **Random Forest** provides the most reliable and robust hard predictions (achieving higher accuracy on this small dataset), while the **MLP** acts as a sensitive feature-miner, highlighting the hidden importance of institutional transparency and education in the broader socio-economic fabric.
